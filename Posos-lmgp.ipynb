# %% [markdown]
# # Challenge Posos
# -------------------------

# %% [markdown]
# <b>Contexte :</b>
#
# Plus de 6 000 médicaments différents sont commercialisés en France. Non seulement les patients, mais aussi les professionnels de la santé restent incapables de les utiliser correctement lorsqu'ils n'ont pas un accès immédiat à l'information appropriée qu'ils  recherchent. Les médicaments restent responsables de plus de 144 000 hospitalisations chaque année en France, tandis qu'aux Etats-Unis, 1,5 million de personnes sont confrontées chaque année à un abus de médicaments. Les questions concernant la prescription, la dispensation ou l'utilisation des médicaments ne doivent jamais rester sans réponse. Ce qui est particulièrement intéressant à comprendre au sujet des demandes de renseignements sur les médicaments, c'est ce que les gens s'attendent à obtenir comme réponse : par exemple, les effets secondaires associés, les ingrédients ou les contre-indications. Des millions de questions sont posées chaque année sur les drogues. Il y a un nombre limité de types de requêtes, mais la même question peut être posée de plusieurs façons. Par conséquent, il est très difficile de comprendre l'information que les gens s'attendent à obtenir lorsqu'ils posent une question.
#
# <b>Objectifs :</b>
#
# Prédire pour chaque question l'intention associée.

# %% [markdown]
# <br>
# <br>
#
#
# <u><b><font size=4>Etapes du projet :</font></b></u><br>
# <br>
# 1 - Nous avons entamé cette étude par une <font color=blue><b>exploration des données</b></font>, plus particulièrement sur le champs lexical employé dans les questions.<br><br>
# 2 - Phase de <font color=blue><b>documentation sur les types de réseaux de neuronnes</b></font> adaptés à de la classification multilabel de textes. les réseaux de neuronnes à convolutions et les réseaux de neuronnes récursifs à mémoire courte.<br><br>
# 3 - En parallèle nous nous sommes initiés à quelques méthodes de <font color=blue><b>Natural Language Processing</b></font>.
# En particulier nous avons observé les résultats obtenus à partir de textes encodés en vecteurs denses via word embedding (word2vec) ou en vecteurs sparses codant les caractères.<br><br>
# 4 - Lors de l'encodage par caractère, un <font color=blue><b>poids spécifique a été affecté aux noms des médicaments</b></font> dans les questions.<br><br>
# 5 - Les hyper-paramètres ont été définis par <font color=blue><b>validation croisée</b></font>.<br><br>
# 6 - Les résultats ont été analysés par le biais d'une <font color=blue><b>matrice de confusion</b></font>.<br><br>
# 7 - Enfin, et du fait du déséquilibre très important des classes target, nous nous sommes essayés à l'<font color=blue><b>augmentation de données</b></font> puis nous avons analysé son impact sur la performance de notre modèle.<br><br><br>

# %%
import pandas as pd
# %matplotlib inline
from sklearn.model_selection import train_test_split

# Read POSOS files
raw_df = pd.read_csv("input_train.csv")
target = pd.read_csv("output_train.csv")

# %%
raw_df.describe()
# Out:
#                 ID
# count  8028.000000
# mean   4013.500000
# std    2317.628314
# min       0.000000
# 25%    2006.750000
# 50%    4013.500000
# 75%    6020.250000
# max    8027.000000

# %%
# Exemple de questions posées 
raw_df.head(10)
# Out:
#    ID                                           question
# 0   0  bonjour,  je m suis trompé de forum pour ma qu...
# 1   1  est ce que le motilium me soulagera contre les...
# 2   2  mon médecin m'a prescrit adenyl. au 2ème cache...
# 3   3  Est-ce qu'il existe une forme adaptée aux enfa...
# 4   4  mon  medecin  me soigne  pour  une  rhino  pha...
# 5   5  je viens d'apprendre que je suis enceinte..sav...
# 6   6       atrax n'est-il pas dangereux au long terme ?
# 7   7  je suis sous mercilon. J'ai des nausées et des...
# 8   8                           L'atenolol, c'est quoi ?
# 9   9  je prend trinordiol et à la fin de ma première...

# %% [markdown]
# # Exploration des données

# %%
# Quelle est la répartition des classes target ?
import seaborn as sns
from matplotlib import pyplot as plt

def lmgp_print_intentiorate(target):
    a4_dims = (12, 8)
    
    # Distribution par ratio des intentions
    intention_rate = target["intention"].value_counts(normalize=True).mul(100).round(2).sort_index(ascending=True)

    intention_rate_df = pd.DataFrame({"intention":intention_rate.index, "intention_rate":intention_rate.values})
    fig, ax = plt.subplots(figsize=a4_dims)
    sns.barplot(x="intention", y="intention_rate", data=intention_rate_df, ax=ax)
    
lmgp_print_intentiorate(target)

# %% [markdown]
# L'intention 28 est très fréquente et semble présenter un cas de figure  très spécifique.<br>
# D'autres en revanche sont très peu représentées et risques donc d'être très difficile à prédire.<br>
# On notera les intentions 28, 31, 44 et 22 comme majeures et construirons nos échantillonages appareillés sur les représentations de ces intentions.

# %%
# Quelle est la distribution du nombre de mots par question ?
nb_words = raw_df.question.str.split().apply(len)
a3_dims = (50, 18)
fig, ax = plt.subplots(figsize=a3_dims)
sns.countplot(nb_words, ax = ax)

# %%
# Plot nb words per target class
a4_dims = (18, 12)
raw_df["nb_words"] = nb_words
raw_df["intention"] = target.intention
fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.boxplot(x="intention", y="nb_words", data=raw_df)

# %% [markdown]
# On voit ici, que certaines questions sont extrêmements longues. <br>
# Parfois plus de 100 mots sont rédigés pour poser une question. <br>
# Cela relève plus du tchat de forum qu'une question directe.

# %%
nb_characters = raw_df.question.apply(len)
# Afficher le nombre de caractères moyen par mots en fonction de la variable d'intérêt
raw_df["nb_characs_avg"] = nb_characters/nb_words
fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.boxplot(x="intention", y="nb_characs_avg", data=raw_df)

# %% [markdown]
# Certaines classes se distinguent par leur longueur moyenne de mots.
# Par exemple, la classe 40 est liée à des mots relativement plus longs alors que l'intention de classe 15 est liée à des questions contenant des mots plus courts.

# %% [markdown]
# ### Distribution de la fréquence des maladies les plus communes

# %%
# Le site "doctissimo" liste les maladies les plus fréquentes 
# Nous recensons ici les occurences de ces maladies dans les questions du dataset d'entrainement

# Nous commenceons par retirer les majuscules
#raw_df["question_lower"] = raw_df["question"].apply(lambda x : x.lower())

# Nous listons ces maladies puis nous énumérons leur présence 
frequent_maladies = ["cancer", "alzheimer", "autisme", "parkinson", "migraine", "sclérose", "dépression", "épilepsie", # système nerveux
                    "lymphome", "cholestérol", "hypertension", "infarctus", "cardiovasculaire", "asthme", "bronchiolite", "légionellose", # problèmes respiratoires
                    "endométriose", "fibromes", "herpès", "sida", "mst", "menstruel", # problèmes intimes
                    "acné", "eczéma", "herpès", "lupus", "psoriasis", "zona", # maladies de peau 
                    "reflux", "proctologique", "maux d'estomac","ulcère", "brulures", "maladies chroniques", "vers intestin", # troubles digestifs
                    "arthrose", "lombalgie", "ostéoporose", "polyarthrite", "rhumatisme", "spondylarthopathies", "sciatique" , # os et articulations
                    "allergie", "cataracte", "dmla", "diabète", "hépatite", "malaria", "méningite", "obésité", "paludisme", "phlébite","saturnisme", "thyroide", # grandes maladies
                    "alcoolisme", "dépendance", "tabagisme" # drogues 
                    ]

def look_for_word_occurences(v_words_list):
    nb_occurences = list()
    for freq_mal in v_words_list:
        nb_occurence = raw_df[raw_df["question"].apply(lambda x : x.find(freq_mal))>=0].shape[0]
        nb_occurences.append(nb_occurence)
    frequent_words_occurences_df = pd.DataFrame({"word_list" : v_words_list, "occurences" : nb_occurences})
    maladies_dims = (int(len(v_words_list)/2),12)
    fig, ax = plt.subplots(figsize=maladies_dims)
    ax = sns.barplot( x="word_list", y="occurences", data=frequent_words_occurences_df)
    plt.xticks(rotation=70)
    
look_for_word_occurences(frequent_maladies)
# Out:
# C:\Users\query\Anaconda3_New\envs\tf_gpu\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Ici, les noms de maladies les plus fréquentes sont également fréquentes dans notre jeu d'entrainement lorsque leur terminologie est assez générique. <br>
# Ainsi <b>migraine, allergie, acné,</b> ou <b>dépendance</b> sont fréquemment rencontrés alors que des termes plus "technique" comme <b>lombalgie</b> sont moins fréquents.

# %%
# Quel est l'impact de l'orthographe sur notre recensement ?
look_for_word_occurences(["epatite", "hépatite"])

# %% [markdown]
# Nous voyons ici qu'il sera nécessaire de prendre en considération l'approximation orthographique des mots dnas les questions.<br>
# Deux approches sont alors possible :
# - soit nous entrainons un embedding de mots en espérant croiser suffisament de fois les mêmes fautes d'orthographes pour pouvoir les assimiler à leur mot d'origine
# - soit nous encodons les caractères
#
# Cette deuxième option necessitera des capacité de calcul plus grandes mais nous affranchira de l'approximation de l'orthographe des mots.

# %% [markdown]
# # Preprocessing
# ## Marque de la présence d'un médicament dans une question

# %%
raw_df = pd.read_csv("input_train.csv")
target = pd.read_csv("output_train.csv")
raw_df["intention"] = target.intention

# %%
import pandas as pd
import codecs

# Fichier : CIS_bdpm.txt 
#
# Il contient la liste des médicaments commercialisés ou en arrêt de commercialisation depuis
# moins de trois ans.

doc = codecs.open("./ansm/CIS_bdpm.txt",'rU') 
CIS_bdpm_df = pd.read_csv(doc, sep='\t', header=None)
CIS_bdpm_df.columns = [ "Code_CIS", # (Code Identifiant de Spécialité)
                        "Denomination_medicament", 
                        "Forme_pharmaceutique", 
                        "Voies_administration", # (avec un séparateur « ; » entre chaque valeur quand il y en a
                                                # plusieurs)
                        "Statut-administratif_AMM", # de l’autorisation de mise sur le marché (AMM)
                        "Type_procedure_autorisation", # de mise sur le marché (AMM)
                        "Etat_commercialisation",
                        "Date_AMM", # (format JJ/MM/AAAA)
                        "StatutBdm", # : valeurs possibles : « Alerte » (icône rouge) ou « Warning disponibilité »
                                     #(icône grise)
                        "Numero_autorisation_euro",
                        "Titulaires", # : S’il y a plusieurs titulaires, les valeurs seront séparées par des « ; »
                        "Surveillance_renforcee"]# (triangle noir) : valeurs « Oui » ou « Non »]
CIS_bdpm_df["Code_CIS"] = CIS_bdpm_df["Code_CIS"].astype(int)
CIS_bdpm_df.head()
# Out:
#    Code_CIS                            Denomination_medicament  \
# 0  61266250                A 313 200 000 UI POUR CENT, pommade
# 1  62869109                   A 313 50 000 U.I., capsule molle
# 2  62401060  ABACAVIR MYLAN 300 mg, comprimé pelliculé sécable
# 3  63797011  ABACAVIR SANDOZ 300 mg, comprimé pelliculé séc...
# 4  63431640  ABACAVIR/LAMIVUDINE BIOGARAN 600 mg/300 mg, co...
#
#          Forme_pharmaceutique Voies_administration Statut-administratif_AMM  \
# 0                     pommade              cutanée      Autorisation active
# 1               capsule molle                orale      Autorisation active
# 2  comprimé pelliculé sécable                orale      Autorisation active
# 3  comprimé pelliculé sécable                orale      Autorisation active
# 4          comprimé pelliculé                orale      Autorisation active
#
#   Type_procedure_autorisation Etat_commercialisation    Date_AMM StatutBdm  \
# 0         Procédure nationale         Commercialisée  12/03/1998       NaN
# 1         Procédure nationale         Commercialisée  07/07/1997       NaN
# 2     Procédure décentralisée         Commercialisée  21/02/2018       NaN
# 3     Procédure décentralisée         Commercialisée  30/12/2016       NaN
# 4         Procédure nationale         Commercialisée  14/02/2017       NaN
#
#   Numero_autorisation_euro             Titulaires Surveillance_renforcee
# 0                      NaN   PHARMA DEVELOPPEMENT                    Non
# 1                      NaN   PHARMA DEVELOPPEMENT                    Non
# 2                      NaN              MYLAN SAS                    Non
# 3                      NaN                 SANDOZ                    Non
# 4                      NaN               BIOGARAN                    Non

# %%
# On récupère le nom des médicaments
medicament_list = CIS_bdpm_df.apply(lambda x : x["Denomination_medicament"].split()[0].lower().split("/")[0], axis=1)
medicament_list = medicament_list.unique().tolist()
medicament_list.remove("a")
medicament_list
# Out:
# ['abacavir',
#  'abasaglar',
#  'abelcet',
#  'abies',
#  'abilify',
#  'abraxane',
#  'abrotanum',
#  'absinthium',
#  'abstral',
#  'abufene',
#  'acadione',
#  'acalypha',
#  'acamprosate',
#  'acarbose',
#  'acarizax',
#  'accofil',
#  'accusol',
#  'acebutolol',
#  'aceclofenac',
#  'acetanilidum',
#  'acetate',
#  'aceticum',
#  'acetonum',
#  'acetylcysteine',
#  'acetylleucine',
#  'aciclovir',
#  'acide',
#  'acidrine,',
#  'acidum',
#  'aclasta',
#  'aclotine',
#  'acnetrait',
#  'aconitum',
#  'acorspray',
#  'act-hib',
#  'actaea',
#  'actapulgite',
#  'actheane,',
#  'acti',
#  'acticarbine',
#  'acticarbine,',
#  'actifed',
#  'actifedsign,',
#  'actilyse',
#  'actilyse,',
#  'actiq',
#  'actiskenan',
#  'actisoufre',
#  'actisoufre,',
#  'activelle,',
#  'activir',
#  'activox',
#  'actonel',
#  'actonelcombi',
#  'actosolv',
#  'actrapid',
#  'actron,',
#  'actynox',
#  'acuilix',
#  'acuitel',
#  'acular',
#  'acupan,',
#  'adalate',
#  'adancor',
#  'adapalene',
#  'adartrel',
#  'adasuve',
#  'adcetris',
#  'adcirca',
#  'adempas',
#  'adenoscan',
#  'adenosine',
#  'adenuric',
#  'adenyl',
#  'adepal,',
#  'adiazine',
#  'adonis',
#  'adoport',
#  'adrenaline',
#  'adrenalinum',
#  'adreview',
#  'adriblastine',
#  'adrigyl',
#  'adrovance',
#  'advagraf',
#  'advate',
#  'advil',
#  'advilcaps',
#  'advilgel',
#  'advilmed',
#  'adynovi',
#  'aerius',
#  'aerrane,',
#  'aesculus',
#  'aethiops',
#  'aethusa',
#  'aetoxisclerol',
#  'afinitor',
#  'afstyla',
#  'aftagel,',
#  'aftosium,',
#  'agaricus',
#  'agave',
#  'agiolax,',
#  'agnus',
#  'agomelatine',
#  'agomélatine',
#  'agraphis',
#  'agrastat',
#  'agrimonia',
#  'agrippal,',
#  'agyrax,',
#  'ailanthus',
#  'airomir',
#  'akineton',
#  'akynzeo',
#  'alairgix',
#  'albey',
#  'albumine',
#  'albunorm',
#  'alcaphor,',
#  'alchemilla',
#  'alcool',
#  'aldactazine,',
#  'aldactone',
#  'aldara',
#  'aldirek',
#  'aldomet',
#  'aldosterone',
#  'aldurazyme',
#  'aldyzine,',
#  'alecensa',
#  'alendronate',
#  'alepsal',
#  'aletris',
#  'alevetabs',
#  'alfa-amylase',
#  'alfacalcidol',
#  'alfalastin',
#  'alfalfa',
#  'alfatil',
#  'alfuzosine',
#  'algesal',
#  'algicalm',
#  'alginate',
#  'algisedal,',
#  'algodol',
#  'algotropyl,',
#  'alimta',
#  'alka',
#  'alkeran',
#  'alkonatrem',
#  'allergiflash',
#  'allergocomod,',
#  'allergodil',
#  'allium',
#  'allopurinol',
#  'alloxanum',
#  'alma',
#  'almide',
#  'almogran',
#  'almotriptan',
#  'alodont,',
#  'aloe',
#  'alopexy',
#  'aloplastine,',
#  'alostil',
#  'aloxi',
#  'alpagelle,',
#  'alphacaine',
#  'alphagan',
#  'alprazolam',
#  'alpress',
#  'alprolix',
#  'alprostadil',
#  'alteis',
#  'alteisduo',
#  'althaea',
#  'altim',
#  'altizide',
#  'alumina',
#  'alunbrig',
#  'alverine',
#  'alvesco',
#  'alyostal',
#  'amanita',
#  'amarance,',
#  'amarel',
#  'ambisome',
#  'ambroxol',
#  'ametycine',
#  'amgevita',
#  'amikacine',
#  'amiloride',
#  'aminomix',
#  'aminophylline',
#  'aminoplasmal',
#  'aminostab,',
#  'aminoven',
#  'amiodarone',
#  'amiped,',
#  'amisulpride',
#  'amlodipine',
#  'amlor',
#  'ammi',
#  'ammonaps',
#  'ammonium',
#  'amodex',
#  'amorolfine',
#  'amoxicilline',
#  'ampecyclal',
#  'ampelopsis',
#  'amphosca',
#  'ampicilline',
#  'amsalyo',
#  'amukine',
#  'amycor',
#  'amylium',
#  'amylodiastase,',
#  'anacardium',
#  'anafranil',
#  'anagallis',
#  'anagrelide',
#  'anandron',
#  'anantherum',
#  'anapen',
#  'anastrozole',
#  'anausin',
#  'ancotil',
#  'andractim,',
#  'androcur',
#  'androgel',
#  'androtardyl',
#  'anesderm',
#  'angelica',
#  'angeliq',
#  'angi-spray',
#  'angiocis.',
#  'angiox',
#  'angipax,',
#  'angusta',
#  'angustura',
#  'anisum',
#  'anoro',
#  'ansatipine',
#  'antadys',
#  'antalcalm',
#  'antalnox',
#  'antalyre,',
#  'antarene',
#  'antasol',
#  'anthemis',
#  'antibio',
#  'antigone',
#  'antigrippine',
#  'antimonium',
#  'antistax',
#  'anxemil',
#  'anxietum,',
#  'any',
#  'aotal',
#  'apaisylgel',
#  'aparoxal',
#  'apatite',
#  'aphilan',
#  'aphtoral,',
#  'apidra',
#  'apium',
#  'apocynum',
#  'apokinon',
#  'apranax',
#  'aprepitant',
#  'aprokam',
#  'aprovel',
#  'apsor',
#  'aptivus',
#  'apurone,',
#  'aqua',
#  'aquarest',
#  'aquilegia',
#  'aracytine',
#  'aralia',
#  'aranesp',
#  'arava',
#  'arcalion',
#  'arcoxia',
#  'arestal',
#  'arganova',
#  'argatroban',
#  'argentum',
#  'arginine',
#  'arginotri-b,',
#  'aricept',
#  'arimidex',
#  'arimidex,',
#  'aripiprazole',
#  'aristolochia',
#  'arixtra',
#  'arkogelules',
#  'arnica',
#  'arnicagel,',
#  'arnicalme,',
#  'arnican',
#  'arnigel,',
#  'arolac',
#  'aromasine',
#  'aromasol,',
#  'arphos,',
#  'arsenicum',
#  'art',
#  'artane',
#  'artelac',
#  'artemisia',
#  'artex',
#  'arthro-drainol,',
#  'arthrocine',
#  'arthrodont',
#  'articadent',
#  'artinibsa',
#  'artirem',
#  'artisial,',
#  'artiss,',
#  'artotec',
#  'arum',
#  'arundo',
#  'arzerra',
#  'asa',
#  'asarum',
#  'asasantine',
#  'ascabiol',
#  'ascabiol,',
#  'asclepias',
#  'ascofer',
#  'ascorbate',
#  'asimina',
#  'asmabec',
#  'asmanex',
#  'asmasal',
#  'asmelor',
#  'asparagus',
#  'aspegic',
#  'asperula',
#  'aspidium',
#  'aspirine',
#  'aspro',
#  'asproflash',
#  'atacand',
#  'atarax',
#  'atarax,',
#  'atazanavir',
#  'atebemyxine,',
#  'atenolol',
#  'atepadene',
#  'atorvastatine',
#  'atosiban',
#  'atovaquone',
#  'atracurium',
#  'atriance',
#  'atripla',
#  'atropine',
#  'atropinum',
#  'atrovent',
#  'aturgyl',
#  'atuxane,',
#  'aubagio',
#  'augmentin',
#  'aureomycine',
#  'auricularum,',
#  'aurigoutte,',
#  'aurum',
#  'auxitrans',
#  'avadene',
#  'avamys',
#  'avastin',
#  'avaxim',
#  'avena',
#  'avenoc,',
#  'avlocardyl',
#  'avodart',
#  'avonex',
#  'axeler',
#  'axepim',
#  'axumin',
#  'azactam',
#  'azadose',
#  'azantac',
#  'azarga',
#  'azathioprine',
#  'azilect',
#  'azithromycine',
#  'azopt',
#  'azurite',
#  'azyter',
#  'azzalure,',
#  'b',
#  'b.a.l.,',
#  'bacicoline',
#  'baclofene',
#  'bacterix',
#  'bactrim',
#  'bactrim,',
#  'bactroban',
#  'badiaga',
#  'balcoga',
#  'balsamorhinol,',
#  'balsamum',
#  'balsofumine',
#  'balsolene,',
#  'bambusa',
#  'baptisia',
#  'baraclude',
#  'baritekal',
#  'baryta',
#  'basdene',
#  'basilicum',
#  'baume',
#  'bavencio',
#  'baypress',
#  'bcg-medac,',
#  'beagyne',
#  'bebegel,',
#  'becilan',
#  'beclo-rhino',
#  'beclojet',
#  'beclometasone',
#  'beclospin',
#  'beclospray',
#  'beconase',
#  'becotide',
#  'becozyme,',
#  'bedelix,',
#  'befizal',
#  'beflavine',
#  'belanette',
#  'belara',
#  'belaracontinu',
#  'belivair',
#  'belladonna',
#  'bellis',
#  'belustine',
#  'bemedrex',
#  'bemfola',
#  'benazepril',
#  'bendamustine',
#  'benefix',
#  'benemide',
#  'benepali',
#  'benerva',
#  'benlysta',
#  'benzathine',
#  'benzoe',
#  'benzoicum',
#  'benzolum',
#  'benzydamine',
#  'bepanthen',
#  'bepanthene',
#  'berberis',
#  'berinert',
#  'beriplast',
#  'berocca',
#  'berocca,',
#  'beromun',
#  'besponsa',
#  'beta',
#  'betadine',
#  'betafact',
#  'betaferon',
#  'betagan',
#  'betahistine',
#  'betamethasone',
#  'betaselen,',
#  'betaserc',
#  'betatop',
#  'betaxolol',
#  'betesil',
#  'betmiga',
#  'betnesol',
#  'betneval',
#  'betoptic',
#  'betula',
#  'bevitine',
#  'bexsero',
#  'bi',
#  'bi-qui-nol',
#  'biafine,',
#  'biafineact,',
#  'bicaflac',
#  'bicalutamide',
#  'bicarbonate',
#  'bicavera',
#  'bicirkan,',
#  'bicnu,',
#  'bifluorid,',
#  'bigonist',
#  'biktarvy',
#  'bilaska',
#  'billerol,',
#  'biltricide',
#  'bimatoprost',
#  'binocrit',
#  'biocadextro',
#  'biocalyptol',
#  'biocalyptol,',
#  'biocarde,',
#  'biocidan',
#  'biocidan,',
#  'biodalgic',
#  'biomag',
#  'bionolyte',
#  'biopeg,',
#  'biorgasept',
#  'biotine',
#  'bioxyol,',
#  'biperidys',
#  'biperidysflash',
#  'biphozyl,',
#  'bipreterax',
#  'birodogyl,',
#  'bisacodyl',
#  'biseptine,',
#  'biseptinescrub,',
#  'biseptinespraid,',
#  'bismuth',
#  'bismuthum',
#  'bisoce',
#  'bisolvon',
#  'bisoprolol',
#  'bivalirudine',
#  'blackoids',
#  'bleomycine',
#  'bleu',
#  'blincyto',
#  'blissel',
#  'bocouture',
#  'boldo',
#  'boldoflorine,',
#  'bolinan',
#  'bondronat',
#  'bontefel',
#  'bonviva',
#  'boostrixtetra,',
#  'borax',
#  'boribel',
#  'boripharm',
#  'bortezomib',
#  'bosentan',
#  'bosulif',
#  'botox',
#  'bovista',
#  'breakyl',
#  'brevibloc',
#  'brexin',
#  'briazide',
#  'bricanyl',
#  'bridion',
#  'briem',
#  'brilique',
#  'brimonidine',
#  'brintellix',
#  'brinzolamide',
#  'bristopen',
#  'bromazepam',
#  'bromhydrate',
#  'bromocriptine',
#  'bromum',
#  'broncalene',
#  'broncathiol',
#  'bronchodermine',
#  'bronchodermine,',
#  'bronchodual',
#  'bronchokod',
#  'bronchorectine',
#  'broncoclar',
#  'brufen',
#  'brulex,',
#  'bryonia',
#  'buccobet',
#  'buccolam',
#  'buccosoin,',
#  'budesonide',
#  'bupivacaine',
#  'buprenorphine',
#  'burinex',
#  'busilvex',
#  'buspirone',
#  'busulfan',
#  'butix,',
#  'buxus',
#  'bydureon',
#  'byetta',
#  'cabergoline',
#  'cablivi',
#  'cabometyx',
#  'cacao',
#  'cacit',
#  'cactus',
#  'cadelius',
#  'cadens',
#  'caditar',
#  'cadmium',
#  'caduet',
#  'caelyx',
#  'caladium',
#  'calcarea',
#  'calcibronat',
#  'calcidia',
#  'calcidose',
#  'calciforte',
#  'calcigaurol',
#  'calciparine',
#  'calcipotriol',
#  'calciprat',
#  'calcitonine',
#  'calcium',
#  'calcos',
#  'caldine',
#  'calendoron,',
#  'calendula',
#  'calmixene,',
#  'calotropis',
#  'calperos',
#  'calprimum',
#  'calsyn',
#  'caltha',
#  'caltrate',
#  'calyptol',
#  'camilia,',
#  'camiline',
#  'camphora',
#  'camphrice',
#  'campto',
#  'cancidas',
#  'candesartan',
#  'canol,',
#  'cantabiline',
#  'cantalene,',
#  'capecitabine',
#  'caprelsa',
#  'capsicum',
#  'capsion,',
#  'captea,',
#  'captopril',
#  'carbactive',
#  'carbaglu',
#  'carbamazepine',
#  'carbetocine',
#  'carbo',
#  'carbocaine',
#  'carbocisteine',
#  'carbolevure',
#  'carbolicum',
#  'carbomix',
#  'carboneum',
#  'carbophos',
#  'carboplatine',
#  'carbosylane',
#  'carbosylane,',
#  'carbosymag,',
#  'cardensiel',
#  'cardiocalm,',
#  'cardiocor',
#  'cardiolite.',
#  'cardiomibi',
#  'cardioxane',
#  'carduus',
#  'carlin',
#  'carlytene',
#  'carmyne',
#  'carominthe,',
#  'carteol',
#  'cartrex',
#  'carvecoral',
#  'carvedilol',
#  'cascara',
#  'casenlax',
#  'casodex',
#  'caspofungine',
#  'catacol',
#  'catapressan',
#  'catarstat,',
#  'caulophyllum',
#  'causticum',
#  'caustinerf',
#  'caverject',
#  'cayston',
#  'ceanothus',
#  'cebemyxine,',
#  'cebesine',
#  'cebutid',
#  'cedron',
#  'cefadroxil',
#  'cefaline',
#  'cefalotine',
#  'cefamandole',
#  'cefazoline',
#  'cefepime',
#  'cefixime',
#  'cefotaxime',
#  'cefoxitine',
#  'cefpodoxime',
#  'ceftazidime',
#  'ceftriaxone',
#  'cefuroxime',
#  'celebrex',
#  'celecoxib',
#  'celectol',
#  'celestamine,',
#  'celestene',
#  'celiprolol',
#  'cellcept',
#  'celltop',
#  'celluvisc',
#  'celocurine',
#  'celsentri',
#  'celsior,',
#  'celvapan,',
#  'cemaflavone,',
#  'cephyl,',
#  'cerazette',
#  'cerdelga',
#  'cerestab',
#  'ceretec',
#  'cerezyme',
#  'ceris',
#  'cernevit,',
#  'certican',
#  'cerubidine',
#  'cerulyse',
#  'cervageme',
#  'cervarix,',
#  'cervoxan',
#  'cetavlex',
#  'cetavlon,',
#  'cetirizine',
#  'cetornan',
#  'cetraria',
#  'cetrotide',
#  'cetylpyridinium',
#  'chamomilla',
#  'champix',
#  'charbon',
#  'cheiranthus',
#  'chelidonium',
#  'chenodeoxycholic',
#  'chibro',
#  'chibro-proscar',
#  'chibroxine',
#  'chimaphila',
#  'china',
#  'chininum',
#  'chionanthus',
#  'chirocaïne',
#  'chloralum',
#  'chloraminophene',
#  'chloraprep',
#  'chloraprep,',
#  'chlorhexidine',
#  'chlorhydrate',
#  'chlormadinone',
#  'chloroformium',
#  'chlorumagene,',
#  'chlorure',
#  'chlorydrate',
#  'cholecalciferol',
#  'cholediam,',
#  'choleodoron,',
#  'cholurso',
#  'chondrosulf',
#  'chophytol',
#  'chophytol,',
#  'chromate',
#  'chronadalate',
#  'chrono-indocid',
#  'cialis',
#  'cibacene',
#  'cibadrex',
#  'cicaderma,',
#  'cicatryl,',
#  'cicletanine',
#  'ciclopirox',
#  'cicuta',
#  'cidermex,',
#  'ciella',
#  'ciflox',
#  'ciloxadex',
#  'ciloxan',
#  'cimetidine',
#  'cimipax',
#  'cimzia',
#  'cina',
#  'cineraria',
#  'cinnabaris',
#  'cinnamomum',
#  'cinqaero',
#  'cinryze',
#  'cipralan',
#  'ciprofibrate',
#  'ciprofloxacine',
#  'circadin',
#  'cirkan',
#  'cisatracurium',
#  'cisnaf',
#  'cisplatine',
#  'citalopram',
#  'citrafleet,',
#  'citrate',
#  'citrus',
#  'civigel',
#  'clairyg',
#  'clamoxyl',
#  'claradol',
#  'clareal',
#  'clarelux',
#  'clariscan',
#  'clarithromycine',
#  'clarityne',
#  'clarix',
#  'clastoban',
#  'claventin',
#  'clematis',
#  'cleridium',
#  'cleviprex',
#  'climara',
#  'climaston',
#  'climaxol,',
#  'climene,',
#  'climodiene',
#  'clindafluid',
#  'clindamycine',
#  'clinimix',
#  'clinoleic',
#  'cliptol,',
#  'clobex',
#  'clofarabine',
#  'clomid',
#  'clomipramine',
#  'clopidogrel',
#  'clopixol',
#  'clorotekal',
#  'clottafact',
#  'cloxacilline',
#  'clozapine',
#  'co',
#  'coaprovel',
#  'cobalt',
#  'cobaltum',
#  'cocculine,',
#  'cocculus',
#  'cochlearia',
#  'codedrill',
#  'codoliprane',
#  'codotussyl',
#  'coffea',
#  'cokenzen',
#  'colchicine',
#  'colchicum',
#  'colchimax,',
#  'colimycine',
#  'colistimethate',
#  'collinsonia',
#  'colludol,',
#  'collunovar',
#  'collyre',
#  'colobreathe',
#  'colocynthis',
#  'colofoam,',
#  'colokit,',
#  'colopeg,',
#  'colposeptine,',
#  'colpotrophine',
#  'colpotrophine,',
#  'colprone',
#  'coltramyl',
#  'combantrin',
#  'combigan',
#  'combivir',
#  'combodart',
#  'compensal',
#  'compralfene',
#  'compralgyl',
#  'comtan',
#  'concerta',
#  'condurango',
#  'condyline',
#  'conebilox',
#  'confidex',
#  'conium',
#  'contalax,',
#  'contracne',
#  'contramal',
#  'contrathion',
#  'contre-coups',
#  'convallaria',
#  'convolvulus',
#  'convuline',
#  'coolmetec',
#  'copaxone',
#  'copegus',
#  'coquelusedal',
#  'corbilta',
#  'cordarone',
#  'corgard',
#  'coricide',
#  'corotrope',
#  'correctol',
#  'cortancyl',
#  'cortapaisyl',
#  'cortexan',
#  'cortiment',
#  'cortisal,',
#  'cortisedermyl',
#  'corvasal',
#  'coryzalia,',
#  'cosentyx',
#  'cosidime',
#  'cosimprel',
#  'cosmegen',
#  'cosopt',
#  'cotareg',
#  'cotellic',
#  'coteoula',
#  'cotriatec',
#  'cotrimoxazole',
#  'coumadine',
#  'covatine',
#  'coveram',
#  'coversyl',
#  'cozaar',
#  'crataegus',
#  'creme',
#  'creon',
#  'cresemba',
#  'cresophene,',
#  'crestor',
#  'crifene',
#  'crinone',
#  'cristal',
#  'crixivan',
#  'crocus',
#  'cromabak',
#  'cromadoses',
#  'cromedil',
#  'cromofree',
#  'cromoglicate',
#  'cromoptic',
#  'cromorhinol',
#  'croton',
#  'crysvita',
#  'cubicin',
#  'cuivre',
#  'cuivre-or-argent',
#  'cupressus',
#  'cuprior',
#  'cuprum',
#  'curacne',
#  'curare',
#  'curaspotaqua',
#  'curethyl',
#  'curosurf',
#  'cutacnyl',
#  'cuterpes',
#  'cutisan',
#  'cyanocobalamine',
#  'cyanokit',
#  'cycladol',
#  'cyclamen',
#  'cyclo',
#  'cyclophosphamide',
#  'cymbalta',
#  'cymevan',
#  'cynara',
#  'cynomel',
#  'cypripedium',
#  'cyproterone',
#  'cyramza',
#  'cyrdanax',
#  'cystadane',
#  'cystadrops',
#  'cystagon',
#  'cystine',
#  'cytarabine',
#  'cyteal,',
#  'cytotec',
#  'ca-dtpa',
#  'dacarbazine',
#  'dacogen',
#  'dacryoserum,',
#  'dacryum,',
#  'dacudoses,',
#  'dafalgan',
#  'dafalganhop',
#  'daflon',
#  'daily,',
#  'daivobet',
#  'daivonex',
#  'dakin',
#  'daklinza',
#  'daktarin',
#  'dalacine',
#  'damiana',
#  ...]

# %%
# On ajoute aux noms de médicaments un pattern sur portera un poids plus important qu'un caractère classique 
def lmgp_medicament_marks(raw_df):
    for medicament in medicament_list:
        raw_df["question#"] = raw_df["question"].apply(lambda x : x.replace(' '+medicament+' ', ' '+medicament+"# " ))
    return raw_df

raw_df = lmgp_medicament_marks(raw_df)

# %%
raw_df.head()
# Out:
#    ID                                           question  intention  \
# 0   0  bonjour,  je m suis trompé de forum pour ma qu...         28
# 1   1  est ce que le motilium me soulagera contre les...         31
# 2   2  mon médecin m'a prescrit adenyl. au 2ème cache...         28
# 3   3  Est-ce qu'il existe une forme adaptée aux enfa...         44
# 4   4  mon  medecin  me soigne  pour  une  rhino  pha...         31
#
#                                            question#
# 0  bonjour,  je m suis trompé de forum pour ma qu...
# 1  est ce que le motilium me soulagera contre les...
# 2  mon médecin m'a prescrit adenyl. au 2ème cache...
# 3  Est-ce qu'il existe une forme adaptée aux enfa...
# 4  mon  medecin  me soigne  pour  une  rhino  pha...

# %% [markdown]
# ## Définition du dictionnaire de base et gestion des caractères spéciaux

# %%
from numpy import argmax

# Définition de l'ensemble des caractères possibles
alphabet = 'abcdefghijklmnopqrstuvwxyz0123456789 .?#' # On ajoutele pattern spécial "#" en fin de notre alphabet

# Mapping des caractères aux entiers et vice-versa
char_to_int = dict((c, i) for i, c in enumerate(alphabet))
int_to_char = dict((i, c) for i, c in enumerate(alphabet))

# %% [markdown]
# Quels sont les caracteres qui ne sont pas dans l'alphabet ?

# %%
# Définition des caractères spéciaux
d = {}
for q in raw_df['question']:
    for char in q.lower():
        if char not in char_to_int:
            d[ord(char)]=char
print(d)
# Out:
# {44: ',', 233: 'é', 232: 'è', 39: "'", 224: 'à', 234: 'ê', 244: 'ô', 45: '-', 231: 'ç', 40: '(', 47: '/', 41: ')', 8217: '’', 43: '+', 239: 'ï', 58: ':', 61: '=', 62: '>', 33: '!', 174: '®', 37: '%', 160: '\xa0', 8364: '€', 34: '"', 251: 'û', 238: 'î', 249: 'ù', 38: '&', 226: 'â', 59: ';', 252: 'ü', 8203: '\u200b', 8230: '…', 96: '`', 176: '°', 180: '´', 235: 'ë', 187: '»', 8482: '™', 339: 'œ', 42: '*', 171: '«', 177: '±', 91: '[', 93: ']', 95: '_', 64: '@', 168: '¨', 186: 'º', 8226: '•', 125: '}'}

# %% [markdown]
# Construction d'un dictionnaire de remplacement des caracteres spéciaux ({code ascii : caractère de remplacement})

# %%
rdict = {44: ' ', 233: 'e', 232: 'e', 39: " ", 224: 'a', 234: 'e', 244: 'o', 45: ' ', 231: 'c', 40: ' ', 47: ' ', 41: ' ', 8217: ' ', 43: ' ', 239: 'i', 58: ' ', 61: ' ', 62: ' ', 33: ' ', 174: ' ', 37: ' ', 160: ' ', 8364: ' euros ', 34: ' ', 251: 'u', 238: 'i', 249: 'u', 38: ' et ', 226: 'a', 59: ' ', 252: 'u', 8203: ' ', 8230: ' ', 96: ' ', 176: ' degres ', 180: ' ', 235: 'e', 187: ' ', 8482: ' ', 339: 'oe', 42: ' fois ', 171: ' ', 177: ' plus ou moins ', 91: ' ', 93: ' ', 95: ' ', 64: ' ', 168: ' ', 186: ' ', 8226: ' ', 125: ' '}

# %% [markdown]
# Substitution des caractères spéciaux

# %%
# On remplace les caractères spéciaux dans les questions
def lmgp_process_words(s):
    
    s = s.lower()
    for t in rdict:
        s=s.replace(chr(t),rdict[t])
        
    s=s.replace("   "," ")
    s=s.replace("  "," ")
    return s

raw_df['q2']=raw_df['question#'].map(lmgp_process_words)

# %% [markdown]
# ## Choix d'une longueur maximale pour nos questions

# %%
def lmgp_question_len(raw_df):
    raw_df['lq2']=0
    question_len=[]
    
    # On collecte la longueur de chaque question
    for q in raw_df['q2']:
        question_len.append(len(q))
    raw_df['lq2']=question_len
    return raw_df
    
raw_df = lmgp_question_len(raw_df)

# %%
raw_df.head()
# Out:
#    ID                                           question  intention  \
# 0   0  bonjour,  je m suis trompé de forum pour ma qu...         28
# 1   1  est ce que le motilium me soulagera contre les...         31
# 2   2  mon médecin m'a prescrit adenyl. au 2ème cache...         28
# 3   3  Est-ce qu'il existe une forme adaptée aux enfa...         44
# 4   4  mon  medecin  me soigne  pour  une  rhino  pha...         31
#
#                                            question#  \
# 0  bonjour,  je m suis trompé de forum pour ma qu...
# 1  est ce que le motilium me soulagera contre les...
# 2  mon médecin m'a prescrit adenyl. au 2ème cache...
# 3  Est-ce qu'il existe une forme adaptée aux enfa...
# 4  mon  medecin  me soigne  pour  une  rhino  pha...
#
#                                                   q2  lq2
# 0  bonjour je m suis trompe de forum pour ma ques...  408
# 1  est ce que le motilium me soulagera contre les...   55
# 2  mon medecin m a prescrit adenyl. au 2eme cache...  316
# 3  est ce qu il existe une forme adaptee aux enfa...   73
# 4  mon medecin me soigne pour une rhino pharingit...  139

# %% [markdown]
# ### Définion d'une longueur Max
# ------------
# Nous allons travailler sur les questions de longueur <= LMAX telle que nous conservons 98% de nos données

# %%
import numpy as np 
q_len = raw_df.apply(lambda x : len(x["question"]), axis=1)
np.percentile(q_len,98)
# Out:
# 446.46000000000004

# %% [markdown]
# On peut donc arrondir un maximum de caractères à analyser pour conserver un peu plus de 98% des questions à classifier

# %%
lmax = 450

# %%
# Completion des question plus courtes 
def pad(s,pad=lmax):
    l=len(s)
    to_return = s
    if pad > l:
        n=pad-l
        to_return = s+' '*n
    
    return to_return

def lmgp_resize_question(raw_df, target, lmax):
    
    # On raccourcit les questions trop longues 
    raw_df["q2"] = raw_df.apply(lambda x : x["q2"][:450], axis=1)

    raw_df2 = raw_df.copy()
    target2=target.copy()

    # On va ensuite compléter les chaines avec des blancs par le biais d'un padding à droite
    raw_df2['q2']=raw_df2['q2'].map(pad)
    raw_df2['lq2']=lmax
    return raw_df2, target2


raw_df2, target2 = lmgp_resize_question(raw_df, target, lmax=450)

# %%
raw_df2['q2'].head().map(len)
# Out:
# 0    450
# 1    450
# 2    450
# 3    450
# 4    450
# Name: q2, dtype: int64

# %% [markdown]
# ### Quelle est la longueur moyenne du premier mot des questions ?

# %%
fw_len = raw_df2.apply(lambda x : len(x["question"].split()[0]), axis=1)
fw_len.mean()
# Out:
# 5.220104633781764

# %% [markdown]
# Le premier mot d'une question a une longueur comprise entre 5 et 6 caractères, un padding à gauche de 5 caractères permettrait par exemple d'optimiser l'exploitation du premier caractère d'une question lors d'une convolution.

# %% [markdown]
# ### Encodage des textes
# ----------------
# On va convertir les questions en coding caracteres (indices dans l'alphabet)

# %%
def lmgp_integer_encoded(s):
    return [char_to_int[char] for char in s]

# %%
def lmgp_encode(raw_df2):
    qlist = [[] for i in range(0,raw_df2.shape[0])]
    i=0
    for c_question in raw_df2['q2']:
        qlist[i]=lmgp_integer_encoded(c_question)
        i+=1
    
    raw_df2['encoded']=qlist
    return raw_df2

raw_df2 = lmgp_encode(raw_df2)

# %%
raw_df2.head()
# Out:
#    ID                                           question  intention  \
# 0   0  bonjour,  je m suis trompé de forum pour ma qu...         28
# 1   1  est ce que le motilium me soulagera contre les...         31
# 2   2  mon médecin m'a prescrit adenyl. au 2ème cache...         28
# 3   3  Est-ce qu'il existe une forme adaptée aux enfa...         44
# 4   4  mon  medecin  me soigne  pour  une  rhino  pha...         31
#
#                                            question#  \
# 0  bonjour,  je m suis trompé de forum pour ma qu...
# 1  est ce que le motilium me soulagera contre les...
# 2  mon médecin m'a prescrit adenyl. au 2ème cache...
# 3  Est-ce qu'il existe une forme adaptée aux enfa...
# 4  mon  medecin  me soigne  pour  une  rhino  pha...
#
#                                                   q2  lq2  \
# 0  bonjour je m suis trompe de forum pour ma ques...  450
# 1  est ce que le motilium me soulagera contre les...  450
# 2  mon medecin m a prescrit adenyl. au 2eme cache...  450
# 3  est ce qu il existe une forme adaptee aux enfa...  450
# 4  mon medecin me soigne pour une rhino pharingit...  450
#
#                                              encoded
# 0  [1, 14, 13, 9, 14, 20, 17, 36, 9, 4, 36, 12, 3...
# 1  [4, 18, 19, 36, 2, 4, 36, 16, 20, 4, 36, 11, 4...
# 2  [12, 14, 13, 36, 12, 4, 3, 4, 2, 8, 13, 36, 12...
# 3  [4, 18, 19, 36, 2, 4, 36, 16, 20, 36, 8, 11, 3...
# 4  [12, 14, 13, 36, 12, 4, 3, 4, 2, 8, 13, 36, 12...

# %% [markdown]
# ## Split Train/test appareillés
# ------------
# Création des jeux de données train/test sur les questions de moins de lmax caractères

# %% [markdown]
# Encodage vecteur 0/1 des questions de "lmax" caractères

# %%
import numpy as np

# Vectorisation des questions en 1 pour tous les caractères et 0.8 le pattern "#" a été inséré
# celui-ci a été inséré à chqque fois qu'un nom d emédicament a été rencontré dans une question
def lmgp_vectorize_questions(questions, lmax=lmax,lalphabet=len(alphabet)):
    results = np.zeros((len(questions), lmax, lalphabet))
    for i, q in enumerate(questions):
        for j, c in enumerate(q):
            # si on rencontre un "#" : 1 sinon 0.5
            results[i, j, c] = .8 if (c==len(alphabet)) else 1.
    return results


def lmgp_split_vectorize(raw_df2, target2, rate):
    
    train2_df, test2_df, train2_target, test2_target = train_test_split(raw_df2, target2.intention,stratify=target2.intention, test_size=rate)
    train2_df["intention"] = pd.DataFrame({'intention':train2_target})
    test2_df["intention"]  = pd.DataFrame({'intention':test2_target})

    x_train = lmgp_vectorize_questions(train2_df.apply(lambda x : x['encoded'][0:450], axis=1))
    x_test = lmgp_vectorize_questions(test2_df.apply(lambda x : x['encoded'][0:450], axis=1))

    # reshape pour la convolution 2D
    x_train = x_train.reshape(x_train.shape[0],x_train.shape[1],x_train.shape[2],1)
    x_test  = x_test.reshape(x_test.shape[0],x_test.shape[1],x_test.shape[2],1)

    return train2_df, test2_df, train2_target, test2_target, x_train, x_test

# %% [markdown]
# ## Définition du réseau avec convolution

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, ZeroPadding2D
from keras.layers import Conv1D,Conv2D, MaxPooling2D
from keras.optimizers import SGD, Adam

# Définition de l'architecture de notre réseau de neuronne à convolution
def build_model():
    model = Sequential()

    model.add(ZeroPadding2D(padding=(5,0), input_shape=(lmax, len(alphabet),1))) # Ajout d'un à gauche pour mieux utiliser les premiers caractères
    model.add(Conv2D(1024, (15,len(alphabet)), activation='relu'))

    model.add(MaxPooling2D(pool_size=(3, 1)))
    model.add(MaxPooling2D(pool_size=(148,1)))
    model.add(Flatten())
    model.add(Dense(2048, activation='relu'))
    model.add(Dense(51, activation='softmax'))
    return model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Validation croisée pour fixer le learning rate

# %%
from sklearn.model_selection import StratifiedKFold
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping


dict_scores = dict()
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=75)    

# Ajouter une boucle sur Adam(lr pour définir la meilleur valeur de lr
for c_lr in [0.0001, 0.0005, 0.001, 0.005]:
    all_scores = list()
    
    for tr_idx, val_idx in skf.split(raw_df2.encoded, target2.intention):    
    
        # split
        x_train = lmgp_vectorize_questions(raw_df2.iloc[tr_idx,].apply(lambda x : x['encoded'][0:450], axis=1))
        x_test = lmgp_vectorize_questions(raw_df2.iloc[val_idx,].apply(lambda x : x['encoded'][0:450], axis=1))
    
        CV_labels_tr, CV_labels_val = target.iloc[tr_idx]['intention'], target.iloc[val_idx]['intention']
    
        y_train = to_categorical(np.asarray(CV_labels_tr).astype('float32'))
        y_test = to_categorical(np.asarray(CV_labels_val).astype('float32'))
    
        # reshape pour la convolution 2D
        x_train = x_train.reshape(x_train.shape[0],x_train.shape[1],x_train.shape[2],1)
        x_test  = x_test.reshape(x_test.shape[0],x_test.shape[1],x_test.shape[2],1)

        # Préparation du modèle 
        model = build_model()
        adam = Adam(lr=c_lr, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

        # Exécution
        es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
        model.compile (optimizer=adam,loss='categorical_crossentropy', metrics=['acc'])
        history = model.fit(x_train, y_train,
                            validation_data=(x_test, y_test),
                            epochs=30,
                            verbose=1,
                            #callbacks = [es],
                            batch_size=32)    
            
        val_acc = model.evaluate(x_test, y_test, verbose=0)
        all_scores.append(val_acc)
    
        dict_scores[c_lr] = np.mean(all_scores)
# Out:
# WARNING:tensorflow:From C:\Users\query\Anaconda3_New\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\query\Anaconda3_New\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 5336 samples, validate on 2692 samples
# Epoch 1/30
# 5336/5336 [==============================] - 19s 4ms/step - loss: 3.2509 - acc: 0.2232 - val_loss: 3.0749 - val_acc: 0.2225
# Epoch 2/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 2.9498 - acc: 0.2614 - val_loss: 2.8349 - val_acc: 0.3068
# Epoch 3/30
# 5336/5336 [==============================] - 17s 3ms/step - loss: 2.6429 - acc: 0.3656 - val_loss: 2.5512 - val_acc: 0.3926
# Epoch 4/30
# 5336/5336 [==============================] - 17s 3ms/step - loss: 2.3466 - acc: 0.4338 - val_loss: 2.3610 - val_acc: 0.4183
# Epoch 5/30
# 5336/5336 [==============================] - 17s 3ms/step - loss: 2.1016 - acc: 0.4874 - val_loss: 2.2091 - val_acc: 0.4551
# Epoch 6/30
# 5336/5336 [==============================] - 16s 3ms/step - loss: 1.8819 - acc: 0.5442 - val_loss: 2.0729 - val_acc: 0.4881
# Epoch 7/30
# 5336/5336 [==============================] - 13s 2ms/step - loss: 1.6745 - acc: 0.5916 - val_loss: 1.9699 - val_acc: 0.5126
# Epoch 8/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 1.4919 - acc: 0.6366 - val_loss: 1.8763 - val_acc: 0.5379
# Epoch 9/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 1.3181 - acc: 0.6735 - val_loss: 1.8009 - val_acc: 0.5598
# Epoch 10/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 1.1714 - acc: 0.7138 - val_loss: 1.7336 - val_acc: 0.5788
# Epoch 11/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 1.0376 - acc: 0.7494 - val_loss: 1.6997 - val_acc: 0.5769
# Epoch 12/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.9169 - acc: 0.7845 - val_loss: 1.6787 - val_acc: 0.5918
# Epoch 13/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.8146 - acc: 0.8118 - val_loss: 1.6331 - val_acc: 0.5992
# Epoch 14/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.7214 - acc: 0.8385 - val_loss: 1.6267 - val_acc: 0.6118
# Epoch 15/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.6377 - acc: 0.8668 - val_loss: 1.6115 - val_acc: 0.6163
# Epoch 16/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.5601 - acc: 0.8855 - val_loss: 1.6138 - val_acc: 0.6118
# Epoch 17/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.4923 - acc: 0.9050 - val_loss: 1.6017 - val_acc: 0.6170
# Epoch 18/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.4322 - acc: 0.9245 - val_loss: 1.5955 - val_acc: 0.6189
# Epoch 19/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.3741 - acc: 0.9338 - val_loss: 1.6109 - val_acc: 0.6200
# Epoch 20/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.3252 - acc: 0.9483 - val_loss: 1.6244 - val_acc: 0.6196
# Epoch 21/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.2799 - acc: 0.9573 - val_loss: 1.6239 - val_acc: 0.6244
# Epoch 22/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.2450 - acc: 0.9668 - val_loss: 1.6717 - val_acc: 0.6178
# Epoch 23/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.2110 - acc: 0.9738 - val_loss: 1.6302 - val_acc: 0.6270
# Epoch 24/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.1800 - acc: 0.9788 - val_loss: 1.6735 - val_acc: 0.6241
# Epoch 25/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.1566 - acc: 0.9839 - val_loss: 1.6738 - val_acc: 0.6159
# Epoch 26/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.1370 - acc: 0.9859 - val_loss: 1.7045 - val_acc: 0.6215
# Epoch 27/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.1141 - acc: 0.9918 - val_loss: 1.7040 - val_acc: 0.6322
# Epoch 28/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.1027 - acc: 0.9914 - val_loss: 1.6942 - val_acc: 0.6293
# Epoch 29/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0910 - acc: 0.9925 - val_loss: 1.7252 - val_acc: 0.6222
# Epoch 30/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0793 - acc: 0.9934 - val_loss: 1.7514 - val_acc: 0.6256
# Train on 5350 samples, validate on 2678 samples
# Epoch 1/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 3.2589 - acc: 0.2228 - val_loss: 3.0652 - val_acc: 0.2240
# Epoch 2/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 2.9501 - acc: 0.2671 - val_loss: 2.8413 - val_acc: 0.3137
# Epoch 3/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 2.6677 - acc: 0.3604 - val_loss: 2.5616 - val_acc: 0.3966
# Epoch 4/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 2.3729 - acc: 0.4305 - val_loss: 2.3371 - val_acc: 0.4264
# Epoch 5/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 2.1145 - acc: 0.4882 - val_loss: 2.1824 - val_acc: 0.4705
# Epoch 6/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 1.8880 - acc: 0.5422 - val_loss: 2.0551 - val_acc: 0.5011
# Epoch 7/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 1.6804 - acc: 0.5994 - val_loss: 1.9593 - val_acc: 0.5258
# Epoch 8/30
# 5350/5350 [==============================] - 13s 2ms/step - loss: 1.4972 - acc: 0.6443 - val_loss: 1.8820 - val_acc: 0.5400
# Epoch 9/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 1.3273 - acc: 0.6839 - val_loss: 1.7850 - val_acc: 0.5672
# Epoch 10/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 1.1775 - acc: 0.7176 - val_loss: 1.7279 - val_acc: 0.5713
# Epoch 11/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 1.0451 - acc: 0.7514 - val_loss: 1.6863 - val_acc: 0.5836
# Epoch 12/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.9301 - acc: 0.7806 - val_loss: 1.6487 - val_acc: 0.5866
# Epoch 13/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.8279 - acc: 0.8052 - val_loss: 1.6389 - val_acc: 0.5986
# Epoch 14/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.7369 - acc: 0.8361 - val_loss: 1.6055 - val_acc: 0.6057
# Epoch 15/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.6492 - acc: 0.8568 - val_loss: 1.6156 - val_acc: 0.6072
# Epoch 16/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.5726 - acc: 0.8837 - val_loss: 1.5957 - val_acc: 0.6109
# Epoch 17/30
# 5350/5350 [==============================] - 13s 2ms/step - loss: 0.5087 - acc: 0.8953 - val_loss: 1.5782 - val_acc: 0.6165
# Epoch 18/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.4435 - acc: 0.9153 - val_loss: 1.5754 - val_acc: 0.6206
# Epoch 19/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.3860 - acc: 0.9316 - val_loss: 1.5869 - val_acc: 0.6210
# Epoch 20/30
# 5350/5350 [==============================] - 13s 2ms/step - loss: 0.3350 - acc: 0.9456 - val_loss: 1.6165 - val_acc: 0.6206
# Epoch 21/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.2889 - acc: 0.9583 - val_loss: 1.6187 - val_acc: 0.6307
# Epoch 22/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.2504 - acc: 0.9647 - val_loss: 1.6158 - val_acc: 0.6273
# Epoch 23/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.2158 - acc: 0.9755 - val_loss: 1.6114 - val_acc: 0.6344
# Epoch 24/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.1837 - acc: 0.9811 - val_loss: 1.6254 - val_acc: 0.6329
# Epoch 25/30
# 5350/5350 [==============================] - 13s 2ms/step - loss: 0.1580 - acc: 0.9841 - val_loss: 1.6513 - val_acc: 0.6311
# Epoch 26/30
# 5350/5350 [==============================] - 13s 2ms/step - loss: 0.1326 - acc: 0.9897 - val_loss: 1.6623 - val_acc: 0.6258
# Epoch 27/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.1159 - acc: 0.9914 - val_loss: 1.6929 - val_acc: 0.6255
# Epoch 28/30
# 5350/5350 [==============================] - 13s 2ms/step - loss: 0.1006 - acc: 0.9920 - val_loss: 1.6968 - val_acc: 0.6348
# Epoch 29/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0863 - acc: 0.9936 - val_loss: 1.6816 - val_acc: 0.6370
# Epoch 30/30
# 5350/5350 [==============================] - 13s 2ms/step - loss: 0.0757 - acc: 0.9933 - val_loss: 1.7232 - val_acc: 0.6262
# Train on 5370 samples, validate on 2658 samples
# Epoch 1/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 3.2537 - acc: 0.2216 - val_loss: 3.0579 - val_acc: 0.2408
# Epoch 2/30
# 5370/5370 [==============================] - 13s 2ms/step - loss: 2.9421 - acc: 0.2724 - val_loss: 2.8100 - val_acc: 0.3299
# Epoch 3/30
# 5370/5370 [==============================] - 13s 2ms/step - loss: 2.6374 - acc: 0.3661 - val_loss: 2.5523 - val_acc: 0.3890
# Epoch 4/30
# 5370/5370 [==============================] - 13s 2ms/step - loss: 2.3510 - acc: 0.4335 - val_loss: 2.3834 - val_acc: 0.4138
# Epoch 5/30
# 5370/5370 [==============================] - 13s 2ms/step - loss: 2.1176 - acc: 0.4786 - val_loss: 2.2298 - val_acc: 0.4496
# Epoch 6/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 1.9004 - acc: 0.5318 - val_loss: 2.1140 - val_acc: 0.4786
# Epoch 7/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 1.7012 - acc: 0.5866 - val_loss: 2.0165 - val_acc: 0.4981
# Epoch 8/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 1.5060 - acc: 0.6384 - val_loss: 1.9075 - val_acc: 0.5241
# Epoch 9/30
# 5370/5370 [==============================] - 13s 2ms/step - loss: 1.3376 - acc: 0.6758 - val_loss: 1.8331 - val_acc: 0.5463
# Epoch 10/30
# 5370/5370 [==============================] - 13s 2ms/step - loss: 1.1892 - acc: 0.7136 - val_loss: 1.7813 - val_acc: 0.5553
# Epoch 11/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 1.0521 - acc: 0.7512 - val_loss: 1.7439 - val_acc: 0.5572
# Epoch 12/30
# 5370/5370 [==============================] - 13s 2ms/step - loss: 0.9334 - acc: 0.7806 - val_loss: 1.7146 - val_acc: 0.5869
# Epoch 13/30
# 5370/5370 [==============================] - 13s 2ms/step - loss: 0.8296 - acc: 0.8104 - val_loss: 1.6893 - val_acc: 0.5914
# Epoch 14/30
# 5370/5370 [==============================] - 13s 2ms/step - loss: 0.7329 - acc: 0.8337 - val_loss: 1.6664 - val_acc: 0.6031
# Epoch 15/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.6473 - acc: 0.8628 - val_loss: 1.6665 - val_acc: 0.6038
# Epoch 16/30
# 5370/5370 [==============================] - 13s 2ms/step - loss: 0.5720 - acc: 0.8812 - val_loss: 1.6574 - val_acc: 0.6012
# Epoch 17/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.5010 - acc: 0.9028 - val_loss: 1.6508 - val_acc: 0.6140
# Epoch 18/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.4388 - acc: 0.9182 - val_loss: 1.6516 - val_acc: 0.6174
# Epoch 19/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.3812 - acc: 0.9356 - val_loss: 1.6593 - val_acc: 0.6215
# Epoch 20/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.3334 - acc: 0.9441 - val_loss: 1.6696 - val_acc: 0.6226
# Epoch 21/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.2872 - acc: 0.9585 - val_loss: 1.6753 - val_acc: 0.6242
# Epoch 22/30
# 5370/5370 [==============================] - 13s 2ms/step - loss: 0.2479 - acc: 0.9646 - val_loss: 1.6851 - val_acc: 0.6238
# Epoch 23/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.2130 - acc: 0.9736 - val_loss: 1.7170 - val_acc: 0.6144
# Epoch 24/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1830 - acc: 0.9797 - val_loss: 1.7117 - val_acc: 0.6185
# Epoch 25/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.1583 - acc: 0.9862 - val_loss: 1.7272 - val_acc: 0.6260
# Epoch 26/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1369 - acc: 0.9875 - val_loss: 1.7359 - val_acc: 0.6219
# Epoch 27/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1172 - acc: 0.9901 - val_loss: 1.7756 - val_acc: 0.6121
# Epoch 28/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0996 - acc: 0.9933 - val_loss: 1.7735 - val_acc: 0.6253
# Epoch 29/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0862 - acc: 0.9942 - val_loss: 1.8004 - val_acc: 0.6166
# Epoch 30/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0748 - acc: 0.9939 - val_loss: 1.7908 - val_acc: 0.6272
# Train on 5336 samples, validate on 2692 samples
# Epoch 1/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 2.9919 - acc: 0.2753 - val_loss: 2.5721 - val_acc: 0.3715
# Epoch 2/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 2.1818 - acc: 0.4651 - val_loss: 2.0466 - val_acc: 0.5208
# Epoch 3/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 1.4926 - acc: 0.6239 - val_loss: 1.7685 - val_acc: 0.5568
# Epoch 4/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.9557 - acc: 0.7547 - val_loss: 1.5683 - val_acc: 0.6122
# Epoch 5/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.5902 - acc: 0.8600 - val_loss: 1.6616 - val_acc: 0.5951
# Epoch 6/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.3443 - acc: 0.9312 - val_loss: 1.6022 - val_acc: 0.6311
# Epoch 7/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.1983 - acc: 0.9723 - val_loss: 1.6787 - val_acc: 0.6237
# Epoch 8/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.1170 - acc: 0.9880 - val_loss: 1.6527 - val_acc: 0.6434
# Epoch 9/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0871 - acc: 0.9918 - val_loss: 1.7026 - val_acc: 0.6423
# Epoch 10/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0692 - acc: 0.9931 - val_loss: 1.7354 - val_acc: 0.6389
# Epoch 11/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0639 - acc: 0.9942 - val_loss: 1.8710 - val_acc: 0.6252
# Epoch 12/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0580 - acc: 0.9931 - val_loss: 1.9239 - val_acc: 0.6204
# Epoch 13/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.0507 - acc: 0.9938 - val_loss: 1.8145 - val_acc: 0.6352
# Epoch 14/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0486 - acc: 0.9938 - val_loss: 1.7720 - val_acc: 0.6415
# Epoch 15/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0477 - acc: 0.9938 - val_loss: 1.7904 - val_acc: 0.6452
# Epoch 16/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0518 - acc: 0.9934 - val_loss: 1.7854 - val_acc: 0.6367
# Epoch 17/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0382 - acc: 0.9936 - val_loss: 1.8242 - val_acc: 0.6445
# Epoch 18/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0349 - acc: 0.9944 - val_loss: 1.8388 - val_acc: 0.6393
# Epoch 19/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0397 - acc: 0.9938 - val_loss: 1.9038 - val_acc: 0.6367
# Epoch 20/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0328 - acc: 0.9942 - val_loss: 1.9002 - val_acc: 0.6382
# Epoch 21/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0323 - acc: 0.9938 - val_loss: 1.8541 - val_acc: 0.6464
# Epoch 22/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0479 - acc: 0.9891 - val_loss: 2.2580 - val_acc: 0.5940
# Epoch 23/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0749 - acc: 0.9852 - val_loss: 2.0431 - val_acc: 0.6118
# Epoch 24/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0542 - acc: 0.9874 - val_loss: 2.0510 - val_acc: 0.6233
# Epoch 25/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0346 - acc: 0.9925 - val_loss: 1.9925 - val_acc: 0.6393
# Epoch 26/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0239 - acc: 0.9942 - val_loss: 2.0126 - val_acc: 0.6360
# Epoch 27/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0212 - acc: 0.9948 - val_loss: 2.0711 - val_acc: 0.6363
# Epoch 28/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0203 - acc: 0.9946 - val_loss: 2.1113 - val_acc: 0.6356
# Epoch 29/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0174 - acc: 0.9951 - val_loss: 2.1961 - val_acc: 0.6267
# Epoch 30/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0155 - acc: 0.9955 - val_loss: 1.9831 - val_acc: 0.6393
# Train on 5350 samples, validate on 2678 samples
# Epoch 1/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 2.9679 - acc: 0.2809 - val_loss: 2.5409 - val_acc: 0.3667
# Epoch 2/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 2.1629 - acc: 0.4733 - val_loss: 2.0038 - val_acc: 0.4910
# Epoch 3/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 1.4699 - acc: 0.6383 - val_loss: 1.7311 - val_acc: 0.5627
# Epoch 4/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.9398 - acc: 0.7652 - val_loss: 1.5647 - val_acc: 0.6109
# Epoch 5/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.5705 - acc: 0.8626 - val_loss: 1.7081 - val_acc: 0.5948
# Epoch 6/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.3286 - acc: 0.9340 - val_loss: 1.6147 - val_acc: 0.6314
# Epoch 7/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.1787 - acc: 0.9768 - val_loss: 1.6317 - val_acc: 0.6229
# Epoch 8/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.1130 - acc: 0.9886 - val_loss: 1.6973 - val_acc: 0.6318
# Epoch 9/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.0801 - acc: 0.9912 - val_loss: 1.8108 - val_acc: 0.6184
# Epoch 10/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0684 - acc: 0.9929 - val_loss: 1.7989 - val_acc: 0.6173
# Epoch 11/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0547 - acc: 0.9929 - val_loss: 1.7735 - val_acc: 0.6285
# Epoch 12/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0439 - acc: 0.9946 - val_loss: 1.8624 - val_acc: 0.6311
# Epoch 13/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0483 - acc: 0.9923 - val_loss: 1.8476 - val_acc: 0.6341
# Epoch 14/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0483 - acc: 0.9935 - val_loss: 1.8486 - val_acc: 0.6243
# Epoch 15/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.0395 - acc: 0.9950 - val_loss: 1.8781 - val_acc: 0.6169
# Epoch 16/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0414 - acc: 0.9938 - val_loss: 1.8938 - val_acc: 0.6262
# Epoch 17/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0443 - acc: 0.9918 - val_loss: 1.9085 - val_acc: 0.6117
# Epoch 18/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.0338 - acc: 0.9938 - val_loss: 2.0211 - val_acc: 0.6120
# Epoch 19/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0330 - acc: 0.9936 - val_loss: 1.8786 - val_acc: 0.6258
# Epoch 20/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0291 - acc: 0.9940 - val_loss: 1.8734 - val_acc: 0.6344
# Epoch 21/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0241 - acc: 0.9944 - val_loss: 1.8800 - val_acc: 0.6232
# Epoch 22/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0236 - acc: 0.9950 - val_loss: 1.8705 - val_acc: 0.6326
# Epoch 23/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0186 - acc: 0.9948 - val_loss: 1.9051 - val_acc: 0.6359
# Epoch 24/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.0180 - acc: 0.9955 - val_loss: 1.9087 - val_acc: 0.6337
# Epoch 25/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0201 - acc: 0.9946 - val_loss: 2.0227 - val_acc: 0.6210
# Epoch 26/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0182 - acc: 0.9948 - val_loss: 1.9775 - val_acc: 0.6333
# Epoch 27/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.0188 - acc: 0.9944 - val_loss: 1.9157 - val_acc: 0.6341
# Epoch 28/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0209 - acc: 0.9944 - val_loss: 2.0087 - val_acc: 0.6329
# Epoch 29/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0238 - acc: 0.9944 - val_loss: 2.0155 - val_acc: 0.6229
# Epoch 30/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.1057 - acc: 0.9692 - val_loss: 2.0561 - val_acc: 0.5945
# Train on 5370 samples, validate on 2658 samples
# Epoch 1/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 2.9841 - acc: 0.2745 - val_loss: 2.5721 - val_acc: 0.3868
# Epoch 2/30
# 5370/5370 [==============================] - 13s 2ms/step - loss: 2.1745 - acc: 0.4631 - val_loss: 2.0174 - val_acc: 0.4816
# Epoch 3/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 1.4836 - acc: 0.6250 - val_loss: 1.7307 - val_acc: 0.5730
# Epoch 4/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.9477 - acc: 0.7600 - val_loss: 1.6131 - val_acc: 0.6038
# Epoch 5/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.5728 - acc: 0.8648 - val_loss: 1.5877 - val_acc: 0.6189
# Epoch 6/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.3210 - acc: 0.9318 - val_loss: 1.6959 - val_acc: 0.6181
# Epoch 7/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.1772 - acc: 0.9749 - val_loss: 1.7376 - val_acc: 0.6155
# Epoch 8/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.1092 - acc: 0.9885 - val_loss: 1.7345 - val_acc: 0.6388
# Epoch 9/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.0734 - acc: 0.9918 - val_loss: 1.7968 - val_acc: 0.6287
# Epoch 10/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.0531 - acc: 0.9944 - val_loss: 1.8214 - val_acc: 0.6189
# Epoch 11/30
# 5370/5370 [==============================] - 13s 2ms/step - loss: 0.0519 - acc: 0.9937 - val_loss: 1.9768 - val_acc: 0.6140
# Epoch 12/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0478 - acc: 0.9946 - val_loss: 1.8743 - val_acc: 0.6305
# Epoch 13/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.0468 - acc: 0.9940 - val_loss: 1.9242 - val_acc: 0.6253
# Epoch 14/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.0421 - acc: 0.9946 - val_loss: 2.0448 - val_acc: 0.6245
# Epoch 15/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0367 - acc: 0.9946 - val_loss: 1.9249 - val_acc: 0.6260
# Epoch 16/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0282 - acc: 0.9957 - val_loss: 1.9290 - val_acc: 0.6309
# Epoch 17/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0295 - acc: 0.9948 - val_loss: 1.9279 - val_acc: 0.6242
# Epoch 18/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0312 - acc: 0.9953 - val_loss: 1.9090 - val_acc: 0.6283
# Epoch 19/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0297 - acc: 0.9944 - val_loss: 1.9134 - val_acc: 0.6369
# Epoch 20/30
# 5370/5370 [==============================] - 13s 2ms/step - loss: 0.0239 - acc: 0.9944 - val_loss: 2.1012 - val_acc: 0.6294
# Epoch 21/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0211 - acc: 0.9952 - val_loss: 1.9594 - val_acc: 0.6358
# Epoch 22/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0199 - acc: 0.9953 - val_loss: 1.9190 - val_acc: 0.6351- los
# Epoch 23/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.0155 - acc: 0.9955 - val_loss: 1.9140 - val_acc: 0.6249
# Epoch 24/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0172 - acc: 0.9955 - val_loss: 2.0624 - val_acc: 0.6305
# Epoch 25/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0153 - acc: 0.9959 - val_loss: 2.0133 - val_acc: 0.6317
# Epoch 26/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0164 - acc: 0.9952 - val_loss: 2.0902 - val_acc: 0.6351
# Epoch 27/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0188 - acc: 0.9948 - val_loss: 2.0859 - val_acc: 0.6238
# Epoch 28/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0172 - acc: 0.9946 - val_loss: 2.0356 - val_acc: 0.6384
# Epoch 29/30
# 5370/5370 [==============================] - 13s 2ms/step - loss: 0.0174 - acc: 0.9944 - val_loss: 2.0874 - val_acc: 0.6302
# Epoch 30/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1547 - acc: 0.9603 - val_loss: 2.0501 - val_acc: 0.6110
# Train on 5336 samples, validate on 2692 samples
# Epoch 1/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 2.8134 - acc: 0.3158 - val_loss: 2.3054 - val_acc: 0.4339
# Epoch 2/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 1.8267 - acc: 0.5484 - val_loss: 1.7397 - val_acc: 0.5710
# Epoch 3/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 1.0491 - acc: 0.7221 - val_loss: 1.6115 - val_acc: 0.6022
# Epoch 4/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.5229 - acc: 0.8649 - val_loss: 1.9677 - val_acc: 0.5877
# Epoch 5/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.2517 - acc: 0.9498 - val_loss: 1.6365 - val_acc: 0.6430
# Epoch 6/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.1201 - acc: 0.9828 - val_loss: 1.7758 - val_acc: 0.6341
# Epoch 7/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0921 - acc: 0.9878 - val_loss: 1.7472 - val_acc: 0.6434
# Epoch 8/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0615 - acc: 0.9901 - val_loss: 1.7131 - val_acc: 0.6508
# Epoch 9/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0557 - acc: 0.9914 - val_loss: 1.8570 - val_acc: 0.6319
# Epoch 10/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0375 - acc: 0.9942 - val_loss: 1.8313 - val_acc: 0.6553
# Epoch 11/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.0428 - acc: 0.9927 - val_loss: 1.8678 - val_acc: 0.6159
# Epoch 12/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0331 - acc: 0.9934 - val_loss: 1.8400 - val_acc: 0.6412
# Epoch 13/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0270 - acc: 0.9949 - val_loss: 1.7934 - val_acc: 0.6608
# Epoch 14/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0201 - acc: 0.9951 - val_loss: 1.9061 - val_acc: 0.6478
# Epoch 15/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.0231 - acc: 0.9949 - val_loss: 1.8355 - val_acc: 0.6516
# Epoch 16/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0191 - acc: 0.9951 - val_loss: 1.9321 - val_acc: 0.6519
# Epoch 17/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0155 - acc: 0.9953 - val_loss: 1.9138 - val_acc: 0.6441
# Epoch 18/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0146 - acc: 0.9948 - val_loss: 1.9574 - val_acc: 0.6482
# Epoch 19/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.0151 - acc: 0.9949 - val_loss: 1.9625 - val_acc: 0.6512
# Epoch 20/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0137 - acc: 0.9944 - val_loss: 1.9845 - val_acc: 0.6471
# Epoch 21/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0119 - acc: 0.9948 - val_loss: 1.9899 - val_acc: 0.6430
# Epoch 22/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0125 - acc: 0.9942 - val_loss: 2.0459 - val_acc: 0.6449
# Epoch 23/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0102 - acc: 0.9951 - val_loss: 2.0236 - val_acc: 0.6493
# Epoch 24/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0120 - acc: 0.9948 - val_loss: 2.0931 - val_acc: 0.6482
# Epoch 25/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0118 - acc: 0.9949 - val_loss: 2.0068 - val_acc: 0.6530
# Epoch 26/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0115 - acc: 0.9951 - val_loss: 2.0167 - val_acc: 0.6549
# Epoch 27/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.0128 - acc: 0.9944 - val_loss: 2.0432 - val_acc: 0.6397
# Epoch 28/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.3381 - acc: 0.9069 - val_loss: 2.0742 - val_acc: 0.5765
# Epoch 29/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.3162 - acc: 0.9114 - val_loss: 2.0459 - val_acc: 0.6233
# Epoch 30/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.0844 - acc: 0.9758 - val_loss: 2.3112 - val_acc: 0.6270
# Train on 5350 samples, validate on 2678 samples
# Epoch 1/30
# 5350/5350 [==============================] - 15s 3ms/step - loss: 2.8422 - acc: 0.3064 - val_loss: 2.2870 - val_acc: 0.4503
# Epoch 2/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 1.8234 - acc: 0.5475 - val_loss: 1.8124 - val_acc: 0.5478
# Epoch 3/30
# 5350/5350 [==============================] - 13s 2ms/step - loss: 1.0163 - acc: 0.7372 - val_loss: 1.6794 - val_acc: 0.5960
# Epoch 4/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.4824 - acc: 0.8705 - val_loss: 1.6125 - val_acc: 0.6322
# Epoch 5/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.2153 - acc: 0.9555 - val_loss: 1.7943 - val_acc: 0.6273
# Epoch 6/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.1129 - acc: 0.9817 - val_loss: 1.9313 - val_acc: 0.6019
# Epoch 7/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0863 - acc: 0.9871 - val_loss: 1.8603 - val_acc: 0.6046
# Epoch 8/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0536 - acc: 0.9923 - val_loss: 1.9386 - val_acc: 0.6199
# Epoch 9/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0428 - acc: 0.9921 - val_loss: 1.9588 - val_acc: 0.6333
# Epoch 10/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0377 - acc: 0.9940 - val_loss: 1.8442 - val_acc: 0.6299
# Epoch 11/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0315 - acc: 0.9942 - val_loss: 2.1243 - val_acc: 0.6214
# Epoch 12/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.0284 - acc: 0.9938 - val_loss: 2.1224 - val_acc: 0.6258
# Epoch 13/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0254 - acc: 0.9933 - val_loss: 2.0740 - val_acc: 0.6359
# Epoch 14/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0222 - acc: 0.9940 - val_loss: 1.9118 - val_acc: 0.6419
# Epoch 15/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.0210 - acc: 0.9938 - val_loss: 1.9694 - val_acc: 0.6471
# Epoch 16/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0181 - acc: 0.9948 - val_loss: 1.9971 - val_acc: 0.6400
# Epoch 17/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0162 - acc: 0.9944 - val_loss: 1.9356 - val_acc: 0.6415
# Epoch 18/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0143 - acc: 0.9944 - val_loss: 1.9626 - val_acc: 0.6497
# Epoch 19/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.0134 - acc: 0.9944 - val_loss: 1.9593 - val_acc: 0.6408
# Epoch 20/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.0127 - acc: 0.9946 - val_loss: 1.9642 - val_acc: 0.6419
# Epoch 21/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.0130 - acc: 0.9951 - val_loss: 2.0543 - val_acc: 0.6314
# Epoch 22/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0122 - acc: 0.9944 - val_loss: 2.0169 - val_acc: 0.6363
# Epoch 23/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.0125 - acc: 0.9946 - val_loss: 2.0440 - val_acc: 0.6475
# Epoch 24/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0116 - acc: 0.9951 - val_loss: 2.0408 - val_acc: 0.6385
# Epoch 25/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0134 - acc: 0.9940 - val_loss: 2.0638 - val_acc: 0.6486
# Epoch 26/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.0537 - acc: 0.9847 - val_loss: 2.8318 - val_acc: 0.5530
# Epoch 27/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.4841 - acc: 0.8578 - val_loss: 2.2412 - val_acc: 0.5586
# Epoch 28/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.1406 - acc: 0.9585 - val_loss: 2.3342 - val_acc: 0.6229
# Epoch 29/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.0628 - acc: 0.9836 - val_loss: 2.4465 - val_acc: 0.6117
# Epoch 30/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.0288 - acc: 0.9918 - val_loss: 2.3489 - val_acc: 0.6367
# Train on 5370 samples, validate on 2658 samples
# Epoch 1/30
# 5370/5370 [==============================] - 15s 3ms/step - loss: 2.8308 - acc: 0.3112 - val_loss: 2.3625 - val_acc: 0.4176
# Epoch 2/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 1.7845 - acc: 0.5538 - val_loss: 1.7804 - val_acc: 0.5504
# Epoch 3/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.9984 - acc: 0.7359 - val_loss: 1.7720 - val_acc: 0.5594
# Epoch 4/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.4760 - acc: 0.8834 - val_loss: 1.7023 - val_acc: 0.6178
# Epoch 5/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1965 - acc: 0.9594 - val_loss: 1.7606 - val_acc: 0.6211
# Epoch 6/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0870 - acc: 0.9858 - val_loss: 1.9148 - val_acc: 0.6181
# Epoch 7/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0591 - acc: 0.9924 - val_loss: 1.8133 - val_acc: 0.6343
# Epoch 8/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.0486 - acc: 0.9942 - val_loss: 1.8146 - val_acc: 0.6388
# Epoch 9/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0356 - acc: 0.9950 - val_loss: 1.9238 - val_acc: 0.6193
# Epoch 10/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0328 - acc: 0.9950 - val_loss: 1.9099 - val_acc: 0.6381
# Epoch 11/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0279 - acc: 0.9946 - val_loss: 2.0170 - val_acc: 0.6366
# Epoch 12/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0286 - acc: 0.9933 - val_loss: 1.9404 - val_acc: 0.6441
# Epoch 13/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0202 - acc: 0.9950 - val_loss: 2.1621 - val_acc: 0.6249
# Epoch 14/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0183 - acc: 0.9952 - val_loss: 2.0148 - val_acc: 0.6373
# Epoch 15/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0170 - acc: 0.9955 - val_loss: 2.0230 - val_acc: 0.6381
# Epoch 16/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0167 - acc: 0.9955 - val_loss: 1.9353 - val_acc: 0.6441
# Epoch 17/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.0136 - acc: 0.9955 - val_loss: 2.0570 - val_acc: 0.6343
# Epoch 18/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0156 - acc: 0.9953 - val_loss: 2.0953 - val_acc: 0.6317
# Epoch 19/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0137 - acc: 0.9957 - val_loss: 1.9903 - val_acc: 0.6482
# Epoch 20/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0132 - acc: 0.9952 - val_loss: 2.0331 - val_acc: 0.6467
# Epoch 21/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0122 - acc: 0.9955 - val_loss: 2.0299 - val_acc: 0.6460
# Epoch 22/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0129 - acc: 0.9950 - val_loss: 2.1485 - val_acc: 0.6362
# Epoch 23/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0119 - acc: 0.9952 - val_loss: 2.1719 - val_acc: 0.6377
# Epoch 24/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0126 - acc: 0.9952 - val_loss: 2.1161 - val_acc: 0.6486
# Epoch 25/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.0114 - acc: 0.9961 - val_loss: 2.1261 - val_acc: 0.6490
# Epoch 26/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.0123 - acc: 0.9961 - val_loss: 2.1519 - val_acc: 0.6426
# Epoch 27/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.0129 - acc: 0.9953 - val_loss: 2.0366 - val_acc: 0.6475
# Epoch 28/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0123 - acc: 0.9950 - val_loss: 2.1765 - val_acc: 0.6362
# Epoch 29/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.4664 - acc: 0.8724 - val_loss: 1.9614 - val_acc: 0.5843
# Epoch 30/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.3447 - acc: 0.9004 - val_loss: 2.2343 - val_acc: 0.5673
# Train on 5336 samples, validate on 2692 samples
# Epoch 1/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 2.5966 - acc: 0.3714 - val_loss: 1.9650 - val_acc: 0.5267
# Epoch 2/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 1.5764 - acc: 0.5952 - val_loss: 1.7250 - val_acc: 0.5632
# Epoch 3/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.8716 - acc: 0.7541 - val_loss: 1.9807 - val_acc: 0.5914
# Epoch 4/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.4768 - acc: 0.8611 - val_loss: 1.9947 - val_acc: 0.6003
# Epoch 5/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.2947 - acc: 0.9230 - val_loss: 2.2328 - val_acc: 0.5754
# Epoch 6/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.2039 - acc: 0.9457 - val_loss: 2.8878 - val_acc: 0.5765
# Epoch 7/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.1564 - acc: 0.9605 - val_loss: 2.7118 - val_acc: 0.5981
# Epoch 8/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.1600 - acc: 0.9599 - val_loss: 2.7282 - val_acc: 0.5821
# Epoch 9/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.1913 - acc: 0.9440 - val_loss: 3.0283 - val_acc: 0.5802
# Epoch 10/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.2412 - acc: 0.9363 - val_loss: 2.7768 - val_acc: 0.5806
# Epoch 11/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.2385 - acc: 0.9367 - val_loss: 2.9118 - val_acc: 0.5906
# Epoch 12/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.1780 - acc: 0.9537 - val_loss: 3.2835 - val_acc: 0.5736
# Epoch 13/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.1633 - acc: 0.9597 - val_loss: 3.1702 - val_acc: 0.5918
# Epoch 14/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.1248 - acc: 0.9678 - val_loss: 3.3320 - val_acc: 0.5854
# Epoch 15/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.1169 - acc: 0.9704 - val_loss: 3.3765 - val_acc: 0.5527
# Epoch 16/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.1503 - acc: 0.9665 - val_loss: 3.3275 - val_acc: 0.5732
# Epoch 17/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.1846 - acc: 0.9582 - val_loss: 3.3947 - val_acc: 0.5750
# Epoch 18/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.1712 - acc: 0.9612 - val_loss: 3.6778 - val_acc: 0.5806
# Epoch 19/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.1471 - acc: 0.9663 - val_loss: 3.5894 - val_acc: 0.5776
# Epoch 20/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.1700 - acc: 0.9618 - val_loss: 4.2435 - val_acc: 0.5736
# Epoch 21/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.2110 - acc: 0.9545 - val_loss: 4.2032 - val_acc: 0.5706
# Epoch 22/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.1568 - acc: 0.9663 - val_loss: 3.5872 - val_acc: 0.5847
# Epoch 23/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.1114 - acc: 0.9753 - val_loss: 4.2105 - val_acc: 0.5724
# Epoch 24/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.1358 - acc: 0.9736 - val_loss: 4.1743 - val_acc: 0.5892
# Epoch 25/30
# 5336/5336 [==============================] - 13s 3ms/step - loss: 0.1575 - acc: 0.9683 - val_loss: 4.1741 - val_acc: 0.5750
# Epoch 26/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.1737 - acc: 0.9672 - val_loss: 3.9321 - val_acc: 0.5880
# Epoch 27/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.1243 - acc: 0.9754 - val_loss: 4.3693 - val_acc: 0.5784
# Epoch 28/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.1459 - acc: 0.9713 - val_loss: 4.5247 - val_acc: 0.5825
# Epoch 29/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.2154 - acc: 0.9623 - val_loss: 4.4273 - val_acc: 0.5743
# Epoch 30/30
# 5336/5336 [==============================] - 14s 3ms/step - loss: 0.2611 - acc: 0.9537 - val_loss: 4.4897 - val_acc: 0.5724
# Train on 5350 samples, validate on 2678 samples
# Epoch 1/30
# 5350/5350 [==============================] - 15s 3ms/step - loss: 2.5788 - acc: 0.3669 - val_loss: 1.9412 - val_acc: 0.5045
# Epoch 2/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 1.5165 - acc: 0.6017 - val_loss: 1.7084 - val_acc: 0.5754
# Epoch 3/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.8684 - acc: 0.7514 - val_loss: 1.7733 - val_acc: 0.5762
# Epoch 4/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.4653 - acc: 0.8707 - val_loss: 2.0971 - val_acc: 0.5788
# Epoch 5/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.3487 - acc: 0.9006 - val_loss: 2.5330 - val_acc: 0.5512
# Epoch 6/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.2596 - acc: 0.9271 - val_loss: 2.4913 - val_acc: 0.5407
# Epoch 7/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.2108 - acc: 0.9400 - val_loss: 2.4535 - val_acc: 0.6004
# Epoch 8/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.1740 - acc: 0.9544 - val_loss: 2.6244 - val_acc: 0.5829
# Epoch 9/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.1367 - acc: 0.9632 - val_loss: 2.9536 - val_acc: 0.5743
# Epoch 10/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.1733 - acc: 0.9572 - val_loss: 2.7850 - val_acc: 0.5889
# Epoch 11/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.2226 - acc: 0.9454 - val_loss: 3.1057 - val_acc: 0.5605
# Epoch 12/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.2030 - acc: 0.9508 - val_loss: 3.3248 - val_acc: 0.5930
# Epoch 13/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.1437 - acc: 0.9621 - val_loss: 3.2274 - val_acc: 0.5934
# Epoch 14/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.1090 - acc: 0.9712 - val_loss: 3.1527 - val_acc: 0.5807
# Epoch 15/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.1458 - acc: 0.9649 - val_loss: 3.5625 - val_acc: 0.5751
# Epoch 16/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.1858 - acc: 0.9536 - val_loss: 3.7347 - val_acc: 0.5840
# Epoch 17/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.2693 - acc: 0.9430 - val_loss: 3.6379 - val_acc: 0.5807
# Epoch 18/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.2229 - acc: 0.9460 - val_loss: 4.0490 - val_acc: 0.5709
# Epoch 19/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.2024 - acc: 0.9557 - val_loss: 3.9371 - val_acc: 0.5646
# Epoch 20/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.1698 - acc: 0.9624 - val_loss: 3.8749 - val_acc: 0.5739
# Epoch 21/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.1010 - acc: 0.9770 - val_loss: 3.9732 - val_acc: 0.5896
# Epoch 22/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.1255 - acc: 0.9759 - val_loss: 3.9768 - val_acc: 0.5795
# Epoch 23/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.1068 - acc: 0.9755 - val_loss: 4.1223 - val_acc: 0.5650
# Epoch 24/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.1073 - acc: 0.9800 - val_loss: 4.2250 - val_acc: 0.5736
# Epoch 25/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.1752 - acc: 0.9649 - val_loss: 4.5363 - val_acc: 0.5429
# Epoch 26/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.2391 - acc: 0.9535 - val_loss: 4.6379 - val_acc: 0.5743
# Epoch 27/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.3478 - acc: 0.9426 - val_loss: 4.6192 - val_acc: 0.5635
# Epoch 28/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.3246 - acc: 0.9460 - val_loss: 4.8514 - val_acc: 0.5500
# Epoch 29/30
# 5350/5350 [==============================] - 14s 3ms/step - loss: 0.2085 - acc: 0.9621 - val_loss: 4.6701 - val_acc: 0.5564
# Epoch 30/30
# 5350/5350 [==============================] - 13s 3ms/step - loss: 0.1605 - acc: 0.9740 - val_loss: 4.8893 - val_acc: 0.5818
# Train on 5370 samples, validate on 2658 samples
# Epoch 1/30
# 5370/5370 [==============================] - 15s 3ms/step - loss: 2.5529 - acc: 0.3739 - val_loss: 2.0237 - val_acc: 0.4906
# Epoch 2/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 1.4984 - acc: 0.6194 - val_loss: 1.7231 - val_acc: 0.5756
# Epoch 3/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.8261 - acc: 0.7633 - val_loss: 1.9104 - val_acc: 0.5892
# Epoch 4/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.4807 - acc: 0.8631 - val_loss: 2.2140 - val_acc: 0.5730
# Epoch 5/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.2658 - acc: 0.9197 - val_loss: 2.3158 - val_acc: 0.5549
# Epoch 6/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.2267 - acc: 0.9371 - val_loss: 2.7667 - val_acc: 0.5463
# Epoch 7/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1985 - acc: 0.9441 - val_loss: 2.8282 - val_acc: 0.5564
# Epoch 8/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1900 - acc: 0.9467 - val_loss: 2.7004 - val_acc: 0.5816
# Epoch 9/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1718 - acc: 0.9544 - val_loss: 3.2349 - val_acc: 0.5448
# Epoch 10/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1397 - acc: 0.9609 - val_loss: 2.7927 - val_acc: 0.5798
# Epoch 11/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.0966 - acc: 0.9739 - val_loss: 3.0886 - val_acc: 0.5907
# Epoch 12/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.1328 - acc: 0.9685 - val_loss: 3.1719 - val_acc: 0.5862
# Epoch 13/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.1333 - acc: 0.9680 - val_loss: 3.1811 - val_acc: 0.5813
# Epoch 14/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.1655 - acc: 0.9605 - val_loss: 3.4644 - val_acc: 0.5561
# Epoch 15/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.2857 - acc: 0.9350 - val_loss: 3.5159 - val_acc: 0.5843
# Epoch 16/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.2757 - acc: 0.9356 - val_loss: 3.9221 - val_acc: 0.5688
# Epoch 17/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.2549 - acc: 0.9412 - val_loss: 3.6260 - val_acc: 0.5602
# Epoch 18/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1699 - acc: 0.9579 - val_loss: 3.8399 - val_acc: 0.5579
# Epoch 19/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1181 - acc: 0.9708 - val_loss: 3.9349 - val_acc: 0.5865
# Epoch 20/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1178 - acc: 0.9737 - val_loss: 4.0957 - val_acc: 0.5530
# Epoch 21/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1121 - acc: 0.9739 - val_loss: 4.0733 - val_acc: 0.5809
# Epoch 22/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1073 - acc: 0.9765 - val_loss: 4.0229 - val_acc: 0.5643
# Epoch 23/30
# 5370/5370 [==============================] - 13s 3ms/step - loss: 0.0969 - acc: 0.9812 - val_loss: 4.1931 - val_acc: 0.5779
# Epoch 24/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1300 - acc: 0.9730 - val_loss: 4.1302 - val_acc: 0.5628
# Epoch 25/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1551 - acc: 0.9661 - val_loss: 4.5869 - val_acc: 0.5749
# Epoch 26/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1868 - acc: 0.9637 - val_loss: 4.2727 - val_acc: 0.5500
# Epoch 27/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.2201 - acc: 0.9561 - val_loss: 4.3944 - val_acc: 0.5429
# Epoch 28/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.2211 - acc: 0.9598 - val_loss: 4.6538 - val_acc: 0.5632
# Epoch 29/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.1933 - acc: 0.9687 - val_loss: 5.1679 - val_acc: 0.5290
# Epoch 30/30
# 5370/5370 [==============================] - 14s 3ms/step - loss: 0.2866 - acc: 0.9547 - val_loss: 4.9370 - val_acc: 0.5628

# %%
dict_scores
# Out:
# {0.0001: 1.1907277979062787,
#  0.0005: 1.3223325920705398,
#  0.001: 1.4542427958154949,
#  0.005: 2.672168119143968}

# %% [markdown]
# ## Application des hyperparamètres et analyse des résultats

# %%
best_lr = 0.0001

# %%
train2_df, test2_df, train2_target, test2_target, x_train, x_test = lmgp_split_vectorize(raw_df2, target2, 0.2)
# Out:
# C:\Users\query\Anaconda3_New\envs\tf_gpu\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\query\Anaconda3_New\envs\tf_gpu\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# Aperçu de l'encoding

# %%
train2_df['encoded'].head()
# Out:
# 1664    [18, 8, 36, 14, 13, 36, 4, 18, 19, 36, 0, 11, ...
# 6060    [18, 0, 21, 4, 25, 36, 21, 14, 20, 18, 36, 18,...
# 7203    [16, 20, 4, 11, 36, 17, 8, 18, 16, 20, 4, 36, ...
# 3094    [4, 18, 19, 36, 2, 4, 36, 15, 14, 18, 18, 8, 1...
# 2837    [11, 20, 12, 0, 11, 8, 0, 36, 8, 3, 4, 13, 19,...
# Name: encoded, dtype: object

# %% [markdown]
# ## Préparation des données pour alimenter le réseau de neuronnes
# --------------------------
# Conversion des labels

# %%
from keras.utils import to_categorical
y_train = to_categorical(np.asarray(train2_df['intention']).astype('float32'))
y_test = to_categorical(np.asarray(test2_df['intention']).astype('float32'))

# %%
model = build_model()
adam = Adam(lr=best_lr, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

# Synthèse de notre architecture et exécution
model.compile (optimizer=adam,loss='categorical_crossentropy', metrics=['acc'])
model.summary()

history = model.fit(x_train, y_train, 
                            validation_data=(x_test, y_test),
                            epochs=30,
                            verbose=1,
                            batch_size=32)
# Out:
# WARNING:tensorflow:From C:\Users\query\Anaconda3_New\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d_1 (ZeroPaddin (None, 460, 40, 1)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 446, 1, 1024)      615424
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 148, 1, 1024)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 1024)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              2099200
# _________________________________________________________________
# dense_2 (Dense)              (None, 51)                104499
# =================================================================
# Total params: 2,819,123
# Trainable params: 2,819,123
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\query\Anaconda3_New\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 6422 samples, validate on 1606 samples
# Epoch 1/30
# 6422/6422 [==============================] - 20s 3ms/step - loss: 3.2223 - acc: 0.2225 - val_loss: 3.0330 - val_acc: 0.2379
# Epoch 2/30
# 6422/6422 [==============================] - 14s 2ms/step - loss: 2.8700 - acc: 0.2955 - val_loss: 2.7269 - val_acc: 0.3499
# Epoch 3/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 2.5165 - acc: 0.3933 - val_loss: 2.4535 - val_acc: 0.3929
# Epoch 4/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 2.2143 - acc: 0.4553 - val_loss: 2.2576 - val_acc: 0.4502
# Epoch 5/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 1.9630 - acc: 0.5170 - val_loss: 2.1097 - val_acc: 0.4795
# Epoch 6/30
# 6422/6422 [==============================] - 14s 2ms/step - loss: 1.7302 - acc: 0.5797 - val_loss: 1.9680 - val_acc: 0.5168
# Epoch 7/30
# 6422/6422 [==============================] - 14s 2ms/step - loss: 1.5158 - acc: 0.6348 - val_loss: 1.8508 - val_acc: 0.5411
# Epoch 8/30
# 6422/6422 [==============================] - 14s 2ms/step - loss: 1.3300 - acc: 0.6795 - val_loss: 1.7632 - val_acc: 0.5598
# Epoch 9/30
# 6422/6422 [==============================] - 14s 2ms/step - loss: 1.1687 - acc: 0.7174 - val_loss: 1.7091 - val_acc: 0.5679
# Epoch 10/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 1.0307 - acc: 0.7498 - val_loss: 1.6735 - val_acc: 0.5785
# Epoch 11/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.9109 - acc: 0.7815 - val_loss: 1.6507 - val_acc: 0.5878
# Epoch 12/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.7971 - acc: 0.8128 - val_loss: 1.6114 - val_acc: 0.5953
# Epoch 13/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.7053 - acc: 0.8419 - val_loss: 1.6116 - val_acc: 0.5971
# Epoch 14/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.6183 - acc: 0.8664 - val_loss: 1.6170 - val_acc: 0.6096
# Epoch 15/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.5410 - acc: 0.8834 - val_loss: 1.5828 - val_acc: 0.6083
# Epoch 16/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.4666 - acc: 0.9053 - val_loss: 1.5876 - val_acc: 0.6177
# Epoch 17/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.4064 - acc: 0.9242 - val_loss: 1.5927 - val_acc: 0.6177
# Epoch 18/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.3498 - acc: 0.9405 - val_loss: 1.6141 - val_acc: 0.6152
# Epoch 19/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.3007 - acc: 0.9524 - val_loss: 1.6278 - val_acc: 0.6196
# Epoch 20/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.2569 - acc: 0.9634 - val_loss: 1.6078 - val_acc: 0.6245
# Epoch 21/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.2214 - acc: 0.9685 - val_loss: 1.6366 - val_acc: 0.6227
# Epoch 22/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.1882 - acc: 0.9774 - val_loss: 1.6321 - val_acc: 0.6333
# Epoch 23/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.1601 - acc: 0.9824 - val_loss: 1.6660 - val_acc: 0.6270
# Epoch 24/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.1356 - acc: 0.9869 - val_loss: 1.7078 - val_acc: 0.6245
# Epoch 25/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.1162 - acc: 0.9896 - val_loss: 1.7159 - val_acc: 0.6345
# Epoch 26/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.1038 - acc: 0.9908 - val_loss: 1.6969 - val_acc: 0.6345
# Epoch 27/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.0876 - acc: 0.9922 - val_loss: 1.7259 - val_acc: 0.6351
# Epoch 28/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.0761 - acc: 0.9933 - val_loss: 1.7417 - val_acc: 0.6314
# Epoch 29/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.0678 - acc: 0.9930 - val_loss: 1.7505 - val_acc: 0.6333
# Epoch 30/30
# 6422/6422 [==============================] - 15s 2ms/step - loss: 0.0600 - acc: 0.9927 - val_loss: 1.7600 - val_acc: 0.6376

# %%
import matplotlib.pyplot as plt

def lmgp_plot_history(history):
    
    # Plot loss
    loss = history.history['loss'] 
    val_loss = history.history['val_loss']
    epochs = range(1, len(loss) + 1)
    plt.figure()
    plt.plot(epochs, loss, 'bo', label='Training loss') 
    plt.plot(epochs, val_loss, 'b', label='Validation loss') 
    plt.title('Training and validation loss') 
    plt.legend()
    plt.show()

    # Plot accuracy 
    acc_values = history.history['acc'] 
    val_acc_values = history.history['val_acc']
    plt.plot(epochs, acc_values, 'bo', label='Training acc') 
    plt.plot(epochs, val_acc_values, 'b', label='Validation acc') 
    plt.title('Training and validation accuracy') 
    plt.xlabel('Epochs') 
    plt.ylabel('Acc') 
    plt.legend()
    plt.show()


lmgp_plot_history(history)

# %% [markdown]
# Après 4 epochs, notre réseau apprend du bruit et perd en pertinence.

# %% [markdown]
# ## Analyse du résultat
#
# Diagonale matrice de confusion

# %%
from sklearn.metrics import confusion_matrix

pred=[]
for proba in model.predict(x_test):
    pred.append(np.argmax(proba))
    
cm = confusion_matrix(test2_df['intention'], pred)
nbl = cm.shape[0]
for i in range(nbl):
    print(i,":",cm[i,i]," / ",sum(cm[i,:]))
# Out:
# 0 : 23  /  41
# 1 : 1  /  5
# 2 : 2  /  4
# 3 : 0  /  2
# 4 : 8  /  15
# 5 : 8  /  20
# 6 : 3  /  5
# 7 : 2  /  4
# 8 : 15  /  27
# 9 : 5  /  11
# 10 : 6  /  14
# 11 : 24  /  39
# 12 : 9  /  18
# 13 : 16  /  24
# 14 : 38  /  63
# 15 : 1  /  5
# 16 : 2  /  3
# 17 : 1  /  3
# 18 : 2  /  5
# 19 : 2  /  4
# 20 : 2  /  4
# 21 : 22  /  36
# 22 : 73  /  92
# 23 : 26  /  42
# 24 : 10  /  13
# 25 : 4  /  6
# 26 : 5  /  14
# 27 : 6  /  21
# 28 : 297  /  359
# 29 : 3  /  15
# 30 : 4  /  10
# 31 : 63  /  113
# 32 : 33  /  64
# 33 : 16  /  29
# 34 : 47  /  77
# 35 : 1  /  10
# 36 : 1  /  5
# 37 : 11  /  25
# 38 : 10  /  24
# 39 : 0  /  8
# 40 : 0  /  1
# 41 : 2  /  9
# 42 : 37  /  63
# 43 : 9  /  18
# 44 : 85  /  112
# 45 : 5  /  10
# 46 : 6  /  9
# 47 : 14  /  16
# 48 : 59  /  78
# 49 : 2  /  4
# 50 : 3  /  7

# %% [markdown]
# On constate ici qu'il y a une corrélation forte entre le nombre d'erreur et le nombre d'occurrences de ces classes target

# %%
import seaborn as sns

# Transforme un encodage des classes target en valorisation des classes
def lmgp_reverse_dummies(y):
    # Identification de la classe prédite pour chaque ligne du dataset de validation avec la probabilité max
    max_per_line = np.max(y, axis=1)

    # On parcours les prédictions de chaque ligne du dataset de validation
    # et on récupère l'indice de la probabilité de prédiction maximale
    return [ list(y[i]).index(list(max_per_line)[i]) for i in range(0,len(max_per_line))]


def lmgp_analyze_pred(y_pred, y_val, v_class):
    # On récupère les valeurs des classes prédites
    pred_classes_val = lmgp_reverse_dummies(y_pred)
    
    # On transfome de la même façon les classes réelles
    y_classes_val = lmgp_reverse_dummies(y_val)
    
    # On formatte ces résultats dans un dataframe
    y_analyse_df = pd.DataFrame({"y_classes_val":y_classes_val,"pred_classes_val":pred_classes_val})
    pred_for_classe = y_analyse_df.loc[y_analyse_df["y_classes_val"]==v_class, "pred_classes_val"]

    # Distribution par ratio des predictions
    intention_rate = pred_for_classe.value_counts(normalize=True).mul(100).round(2).sort_index(ascending=True)
    intention_rate_df = pd.DataFrame({"intention":intention_rate.index, "intention_rate":intention_rate.values})
        
    fig, ax = plt.subplots(figsize=(12, 8))
    sns.barplot(x="intention", y="intention_rate", data=intention_rate_df, ax=ax)
    plt.title("Prédictions de la classe : "+str(v_class))    

    
def lmgp_display_errors(y_pred, y_val):
    # On récupère les valeurs des classes prédites
    pred_classes_val = lmgp_reverse_dummies(y_pred)
    
    # On transfome de la même façon les classes réelles
    y_classes_val = lmgp_reverse_dummies(y_val)
    
    # On formatte ces résultats dans un dataframe
    y_analyse_df = pd.DataFrame({"y_classes_val":y_classes_val,"pred_classes_val":pred_classes_val})

    #d = pd.DataFrame(0, index=np.arange(len(data)), columns=feature_list)
    
    for v_class in range(1,51):
        pred_for_classe = y_analyse_df.loc[y_analyse_df["y_classes_val"]==v_class, "pred_classes_val"]

        # Distribution par ratio des predictions
        intention_rate = pred_for_classe.value_counts(normalize=True).mul(100).round(2).sort_index(ascending=True)
        intention_rate_df = pd.DataFrame({"intention":intention_rate.index, "intention_rate":intention_rate.values})
        
        
    return y_analyse_df
    

y_pred = model.predict(x_test, verbose=0)

# Construction de la matrice prédictions - valeurs réelles 
df = lmgp_display_errors(y_pred, y_test)
df_mat = df.groupby([ 'y_classes_val', 'pred_classes_val']).size().unstack(fill_value=0).values

# Normalisation des prédictions
row_sums = df_mat.sum(axis=1)
df_mat = df_mat / row_sums[:, np.newaxis]

# Affichage de la matrice des prédictions
fig, ax = plt.subplots(figsize=(18,18))
plt.imshow(df_mat, cmap='hot', interpolation="nearest", extent=[0,50,50,0])
ax.set_title("Y_true Vs Y_pred")

ax = plt.gca()
xticks = range(0,51)
yticks = range(0,51)
ax.set_xticks(xticks)
ax.set_yticks(yticks)

plt.colorbar()
plt.show()

# %% [markdown]
# La matrice de confusion permet de constater que certaines classes sont confondues par notre modèle à convolution.<br>
# Par exemple, la classe 39 n'est jamais reconnue et toujours confondue avec la classe 26

# %%
raw_df.columns
# Out:
# Index(['ID', 'question', 'intention', 'question#', 'q2', 'lq2'], dtype='object')

# %% [markdown]
# ## Définition du réseau avec convolution + LSTM

# %%
X=np.zeros((train2_df.shape[0],lmax),dtype=np.float)
i=0
for l in train2_df.apply(lambda x : x['encoded'][0:450], axis=1).values:
    X[i] = l
    i+=1
X.shape
# Out:
# (6422, 450)

# %%
# TODO

# %% [markdown]
# ## DATA Augmentation
#
# ### Entrainement d'un modèle Word2Vec afin de faire des remplacements par synonyme
#
# -------------

# %% [markdown]
# ####  Entrainement sur le dataset des questions

# %%
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import re
import unicodedata

# Fonction de nettoyage de texte
# option : suppression des "stopwords"
#          restriction au radical
def text_to_wordlist(text, remove_stopwords=False, stem_words=False):
    
    # Convert words to lower case and split them
    text = text.lower().split()

    # Remove stop words if option set
    if remove_stopwords:
        stops = set(stopwords.words("french"))
        text = [w for w in text if not w in stops]
    
    text = " ".join(text)

    # Clean the text
    text = re.sub(r"[^A-Za-z0-9^,.\/éèêùûà'+-=]", " ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"estce", "est ce", text)
    text = re.sub(r"\.", ".", text)     
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"é", "e", text)
    text = re.sub(r"è", "e", text)
    text = re.sub(r"ê", "e", text)
    text = re.sub(r"ù", "u", text)
    text = re.sub(r"û", "u", text)
    text = re.sub(r"à", "a", text)

    text = unicodedata.normalize('NFKD', text)
    
    # Optionally, shorten words to their stems
    if stem_words:
        text = text.split()
        stemmer = SnowballStemmer('french')
        stemmed_words = [stemmer.stem(word) for word in text]
        text = " ".join(stemmed_words)
    
    # Return a list of words
    return(text)

# %%
# On formate les questions 
raw_df["question_cleaned"] = raw_df["question"].apply(lambda x : text_to_wordlist(x, remove_stopwords=True, stem_words= False))

# %%
# Construction du dictionnaire word2Vec sur les questions fournies dans le challenge
from gensim.models import word2vec
import numpy as np

########################################
## Construction du vocab 
########################################
EMBEDDING_DIM = 128
m_epochs = 20
MAX_NB_WORDS = 20000

wv_model = word2vec.Word2Vec(raw_df['question_cleaned'].apply(lambda x : x.split()), 
                          sg=1, # skip gram : utilisé pour les mots rares
                          #negative=5, # negative sampling : pour ajouter du bruit  
                          size=EMBEDDING_DIM, # Vector dimension 
                          window=20, # fenêtre d'encapsulage des mots
                          min_count=1, # min occurences nb
                          workers=1, 
                          iter=m_epochs # epoch
                         )
print('Found %s word vectors of word2vec' % len(wv_model.wv.vocab))
# Out:
# C:\Users\query\Anaconda3_New\envs\tf_gpu\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Found 10890 word vectors of word2vec

# %%
# Sauvegarde du model word2vec
wv_model.save("posos_word2vec.model")
# Out:
# C:\Users\query\Anaconda3_New\envs\tf_gpu\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# ### Chargement du modèle word2vec

# %%
from gensim.models import word2vec
import numpy as np

EMBEDDING_DIM = 128
m_epochs = 100
MAX_NB_WORDS = 20000

# Chargement du model word2vec
wv_model = word2vec.Word2Vec.load("posos_word2vec.model")
# Out:
# C:\Users\query\Anaconda3_New\envs\tf_gpu\lib\site-packages\smart_open\smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# ### Augmentation des données par ajout/suppression et remplacement

# %% [markdown]
# #### Fonction de  suppression d'un caractère

# %%
import random

# On supprime un caractère au hasard
def lmgp_remove_char(a_string):
    index = random.randint(0, len(a_string)-1)
    return a_string[:index] + a_string[index+1:]

# %% [markdown]
# #### Fonction d'ajout de bruits par erreur QWERTY

# %%
# Augmentation des données par substitution des erreurs référencées 
# dans le dictionnaire de liste de valeurs de substitution passé en paramètre
def lmgp_DicList_aug(phrase, dictList):
    
    words_list = phrase.split()
    c_replaced=0
    new_phrase = phrase
    
    # Si il est possible de faire au moins une substitution
    if any(x in phrase for x in list(dictList.keys())):
        
        # Tant que la substitution n'a pas été faite une fois
        while c_replaced==0:
            # On tire un mot à modifier 
            word_to_modify = words_list[random.randint(0, len(words_list)-1)]
            for key, values in dictList.items():
                # Si la substitution peut avoir lieu, arrêt de la fonction
                if key in word_to_modify:
                    value = values[random.randint(0, len(values)-1)]
                    new_word = word_to_modify.replace(key, value)
                    new_phrase = phrase.replace(word_to_modify,new_word)
                    c_replaced = 1

    return new_phrase

# %%
# Dictionnaire des listes d'erreurs de frappe qwerty liées au clavier QWERTY
from collections import defaultdict

# Fonction créant le dictionnaire de listes d'erreurs 
def lmgp_create_dictlist(key_values, dict_qwerty):
        
    for key, cchar in key_values:
        dict_qwerty[key].append(cchar)
    return dict_qwerty

dict_QWERTY = defaultdict(list)
elist = [('e','w'),('e','r'),('e','s'),('e','d'),('e','f')]
dict_QWERTY = lmgp_create_dictlist(elist, dict_QWERTY)

elist = [('h','t'),('h','y'),('h','u'),('h','g'),('h','j')]
dict_QWERTY = lmgp_create_dictlist(elist, dict_QWERTY)

elist = [('k','u'),('k','i'),('k','o'),('k','j'),('k','')]
dict_QWERTY = lmgp_create_dictlist(elist, dict_QWERTY)

# %% [markdown]
# #### Fonction d'ajout de bruits par erreur OCR

# %%
# Dictionnaire des erreurs de conversion des interpréteurs d'images
dict_OCR={'o' : list('0'),
'l' : list('1'),
'b' : list('6')}
   

#lmgp_OCR_aug("Le pere noel est trop gros")
#lmgp_OCR_aug("meme pas vrai!")
lmgp_DicList_aug("il est maigre au liban!", dict_OCR)
# Out:
# 'i1 est maigre au liban!'

# %% [markdown]
# #### Fonction de substitution par similarité vocabulaire word2vec contextuel

# %%
# Ajout de bruit par remplacement de synonym
def lmgp_synonym_aug(question, replacement_rate):
    
    question_splited = question.split()
    question_len = len(question_splited)
    nb_words_to_change = int(question_len * replacement_rate)
    
    # On modifie les mots par un synonyme jusqu'à avoir changé 20% de la phrase
    nb_words_changed = 0
    for word_to_change in question_splited:
        if (word_to_change in wv_model.wv.vocab) & (word_to_change not in stopwords.words("french")):
            question = question.replace( word_to_change, wv_model.wv.similar_by_word(word_to_change)[random.randint(1,2)][0])
            nb_words_changed = nb_words_changed + 1
            
            # Si l'on a changé suffisament de mots on retourne la question transformée
            if nb_words_changed == nb_words_to_change:
                # On retire un caractère au hasard avant de sortir
                question = lmgp_remove_char(question)
                
                return question
        
    return question

# On remplace notre mot par l'un de ses 2 synonymes
lmgp_synonym_aug("la betadine est elle vraiment  bien pour les enfants qui partent en vacances avec leur grands parents tout l ete", 0.2)
# Out:
# 'la eponge est elle parmis trappe pour quinine enfants qui partent en vacances avec leur grands parents tout l ete'

# %% [markdown]
# ### Application des différentes méthodes d'augmentations de données

# %%
# Flow de modification des phrases permettant d'augmenter nos données 
def lmgp_AUG_flow(phrase):
    phrase = lmgp_remove_char(phrase)
    phrase = lmgp_DicList_aug(phrase, dict_QWERTY)
    phrase = lmgp_DicList_aug(phrase, dict_OCR)
    phrase = lmgp_remove_char(phrase)
    phrase = lmgp_DicList_aug(phrase, dict_QWERTY)
    phrase = lmgp_DicList_aug(phrase, dict_OCR)
    phrase = lmgp_synonym_aug(phrase, 0.2)
    return phrase

# %% [markdown]
# # Preprocessing des données + data augmentation

# %%
raw_df = pd.read_csv("input_train.csv")
target = pd.read_csv("output_train.csv")
raw_df["intention"] = target.intention

# %%
# Listing des classes sous représentées, moins de 1%
threshol_rate = 1

def lmgp_data_augmentation(raw_df, target, threshol_rate = 1):
    
    intention_rate = target["intention"].value_counts(normalize=True).mul(100).round(2).sort_index(ascending=True)   
    weak_classes = list(intention_rate[intention_rate<threshol_rate].index)
    weak_classes_df = pd.DataFrame({"weak_classes" : weak_classes})

    # calcul du nombre de d'exécution de la procédure de création de données 
    # pour cela on souhaite que chaque classe ayant moins de "threshold_rate" points 
    # soit augmentée jusqu'à avoir l'équivalent de 20% des points initiaux
    weak_classes_df["nb_ops"] = (20/intention_rate).apply(lambda x : int(x)+1)

    # Initialisation de la nouvelles liste des données
    new_question_list = list(raw_df["question"].copy())
    new_target_list = list(target["intention"].copy())

    # Augmentation des données
    wclasses = list(weak_classes_df["weak_classes"])
    nb_ops_s = list( weak_classes_df["nb_ops"])

    
    for i, wclass in enumerate(wclasses):
        nb_ops = nb_ops_s[i]
        questions = raw_df.loc[target.intention==wclass, "question"]
        for question in questions :
            for i in range(1, (nb_ops+1)):
                #print(question)
                #question = lmgp_AUG_flow(question)
                new_question_list.append(lmgp_AUG_flow(question))
                new_target_list.append(wclass)

    raw_df = pd.DataFrame({"question":new_question_list,"intention":new_target_list})
    
    target = pd.DataFrame({"intention":new_target_list})

    return raw_df, target

# %%
# Split des données
rate=0.2
train2_df, test2_df, train2_target, test2_target = train_test_split(raw_df, target.intention,stratify=target.intention, test_size=rate)
train2_df["intention"] = train2_target.values
test2_df["intention"]  = test2_target.values
train2_target = pd.DataFrame({'intention':train2_target.values})
test2_target = pd.DataFrame({'intention':test2_target.values})

train2_df = train2_df.reset_index(drop=True)
test2_df = test2_df.reset_index(drop=True)
train2_target = train2_target.reset_index(drop=True)
test2_target = test2_target.reset_index(drop=True)


# Ici on augmente les données uniquement sur le train pour éviter toute corrélation entre les 2 dataset train et test
train2_df, train2_target = lmgp_data_augmentation(train2_df, train2_target, threshol_rate = 20)


# PrepProcess Train & Test
# On pose des ancres pour chaque médicament
train2_df = lmgp_medicament_marks(train2_df)
train2_df['q2']=train2_df['question#'].map(lmgp_process_words)
train2_df = lmgp_question_len(train2_df)
train2_df["q2"] = train2_df.apply(lambda x : x["q2"][:450], axis=1)

test2_df = lmgp_medicament_marks(test2_df)
test2_df['q2']=test2_df['question#'].map(lmgp_process_words)
test2_df = lmgp_question_len(test2_df)
test2_df["q2"] = test2_df.apply(lambda x : x["q2"][:450], axis=1)

# On encode et on format les données
train2_df, train2_target = lmgp_resize_question(train2_df, train2_target, lmax=450)
train2_df = lmgp_encode(train2_df)
train2_df["intention"] = train2_target["intention"]
train2_df = train2_df.reset_index(drop=True)

test2_df, test2_target = lmgp_resize_question(test2_df, test2_target, lmax=450)
test2_df = lmgp_encode(test2_df)
test2_df["intention"] = test2_target["intention"]
test2_df = test2_df.reset_index(drop=True)


# On vectorize les questions
x_train = lmgp_vectorize_questions(train2_df.apply(lambda x : x['encoded'][0:450], axis=1))
x_test = lmgp_vectorize_questions(test2_df.apply(lambda x : x['encoded'][0:450], axis=1))

# Reshape pour la convolution 2D
x_train = x_train.reshape(x_train.shape[0],x_train.shape[1],x_train.shape[2],1)
x_test  = x_test.reshape(x_test.shape[0],x_test.shape[1],x_test.shape[2],1)
    
from keras.utils import to_categorical
y_train = to_categorical(np.asarray(train2_df['intention']).astype('float32'))
y_test = to_categorical(np.asarray(test2_df['intention']).astype('float32'))
    
model_aug = build_model()
adam = Adam(lr=best_lr, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

# Synthèse de notre architecture et exécution
model_aug.compile (optimizer=adam,loss='categorical_crossentropy', metrics=['acc'])
model_aug.summary()

history_aug = model_aug.fit(x_train, y_train, 
                            validation_data=(x_test, y_test),
                            #callbacks = [es],
                            epochs=20,
                            verbose=1,
                            batch_size=32)
# Out:
# C:\Users\query\Anaconda3_New\envs\tf_gpu\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\query\Anaconda3_New\envs\tf_gpu\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d_2 (ZeroPaddin (None, 460, 40, 1)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 446, 1, 1024)      615424
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 148, 1, 1024)      0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 1024)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2048)              2099200
# _________________________________________________________________
# dense_4 (Dense)              (None, 51)                104499
# =================================================================
# Total params: 2,819,123
# Trainable params: 2,819,123
# Non-trainable params: 0
# _________________________________________________________________
# Train on 110383 samples, validate on 1606 samples
# Epoch 1/20
# 110383/110383 [==============================] - 241s 2ms/step - loss: 1.9848 - acc: 0.5186 - val_loss: 2.1038 - val_acc: 0.4788
# Epoch 2/20
# 110383/110383 [==============================] - 240s 2ms/step - loss: 0.6473 - acc: 0.8475 - val_loss: 1.6905 - val_acc: 0.6046
# Epoch 3/20
# 110383/110383 [==============================] - 240s 2ms/step - loss: 0.2692 - acc: 0.9410 - val_loss: 1.6859 - val_acc: 0.6276
# Epoch 4/20
# 110383/110383 [==============================] - 238s 2ms/step - loss: 0.1147 - acc: 0.9783 - val_loss: 1.7605 - val_acc: 0.6513
# Epoch 5/20
# 110383/110383 [==============================] - 280s 3ms/step - loss: 0.0488 - acc: 0.9929 - val_loss: 1.9619 - val_acc: 0.6432
# Epoch 6/20
# 110383/110383 [==============================] - 262s 2ms/step - loss: 0.0239 - acc: 0.9972 - val_loss: 2.1263 - val_acc: 0.6320
# Epoch 7/20
# 110383/110383 [==============================] - 240s 2ms/step - loss: 0.0147 - acc: 0.9983 - val_loss: 2.2224 - val_acc: 0.6426
# Epoch 8/20
# 110383/110383 [==============================] - 238s 2ms/step - loss: 0.0113 - acc: 0.9985 - val_loss: 2.3371 - val_acc: 0.6532
# Epoch 9/20
# 110383/110383 [==============================] - 240s 2ms/step - loss: 0.0087 - acc: 0.9988 - val_loss: 2.4771 - val_acc: 0.6413
# Epoch 10/20
# 110383/110383 [==============================] - 239s 2ms/step - loss: 0.0089 - acc: 0.9987 - val_loss: 2.5607 - val_acc: 0.6451
# Epoch 11/20
# 110383/110383 [==============================] - 239s 2ms/step - loss: 0.0070 - acc: 0.9991 - val_loss: 2.5507 - val_acc: 0.6507
# Epoch 12/20
# 110383/110383 [==============================] - 239s 2ms/step - loss: 0.0077 - acc: 0.9989 - val_loss: 2.4987 - val_acc: 0.6507
# Epoch 13/20
# 110383/110383 [==============================] - 294s 3ms/step - loss: 0.0061 - acc: 0.9991 - val_loss: 2.5856 - val_acc: 0.6482
# Epoch 14/20
# 110383/110383 [==============================] - 242s 2ms/step - loss: 0.0068 - acc: 0.9990 - val_loss: 2.5486 - val_acc: 0.6582
# Epoch 15/20
# 110383/110383 [==============================] - 241s 2ms/step - loss: 0.0070 - acc: 0.9988 - val_loss: 2.6337 - val_acc: 0.6550
# Epoch 16/20
# 110383/110383 [==============================] - 240s 2ms/step - loss: 0.0053 - acc: 0.9992 - val_loss: 2.6579 - val_acc: 0.6451
# Epoch 17/20
# 110383/110383 [==============================] - 287s 3ms/step - loss: 0.0055 - acc: 0.9992 - val_loss: 2.6256 - val_acc: 0.6557
# Epoch 18/20
# 110383/110383 [==============================] - 241s 2ms/step - loss: 0.0052 - acc: 0.9992 - val_loss: 2.6471 - val_acc: 0.6557
# Epoch 19/20
# 110383/110383 [==============================] - 240s 2ms/step - loss: 0.0053 - acc: 0.9990 - val_loss: 2.7305 - val_acc: 0.6532
# Epoch 20/20
# 110383/110383 [==============================] - 240s 2ms/step - loss: 0.0046 - acc: 0.9992 - val_loss: 2.6860 - val_acc: 0.6457

# %%
lmgp_plot_history(history_aug)

# %%
y_pred = model_aug.predict(x_test, verbose=0)

# Construction de la matrice prédictions - valeurs réelles 
df = lmgp_display_errors(y_pred, y_test)
df_mat = df.groupby([ 'y_classes_val', 'pred_classes_val']).size().unstack(fill_value=0).values

# Normalisation des prédictions
row_sums = df_mat.sum(axis=1)
df_mat = df_mat / row_sums[:, np.newaxis]

# Affichage de la matrice des prédictions
fig, ax = plt.subplots(figsize=(18,18))
plt.imshow(df_mat, cmap='hot', interpolation="nearest", extent=[0,50,50,0])
ax.set_title("Y_true Vs Y_pred")

ax = plt.gca()
xticks = range(0,51)
yticks = range(0,51)
ax.set_xticks(xticks)
ax.set_yticks(yticks)

plt.colorbar()
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# <b>Pour aller plus loin</b>, nous envisagerions d'étudier d'autres architectures de réseaux de convolution et de réseaux récursifs.
# <br>
# <br>Par exemple, le <b>VGGNet Smaller pour les convolutions et une architecture de type GRU</b>.
# <br>Nous rechercherions également un réseau de neuronnes déja entrainé sur de la classification de textes et le ré-exploiterions par <b>transfer learning</b>.
# <br>L'étape d'augmentation des données devrait pouvoir être améliorée via la <b>diversification des méthodes de bruitage et par une substitution par synonymes plus qualitative</b>.
# <br>Nous aimerions également tester une classification hiérarchique afin de gérer le problème de déséquilibre des classes.
# <br>Enfin, un <b>pré-processing plus poussé des questions de train et test</b>, par exemple par la construction d'un dictionnaire de correction des mots type sms : pkoi --> pourquoi, devrait également apporté une amélioration sensible des résultats.
